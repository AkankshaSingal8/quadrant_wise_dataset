# %%
import os
from typing import Iterable, Dict

import csv

import numpy as np
from matplotlib.image import imread
from tqdm import tqdm
from PIL import Image

import seaborn as sns
import pandas as pd
import scipy.io

import cv2

# %%
# !pwd
# Out:
# /src/drone_causality/quadrant_wise_dataset

# %%
# CONVERTING MAT TO CSV FILE 
def mat_to_csv(dataset_directory):

    # Iterate through directories in the dataset directory
    for i in range(len(os.listdir(dataset_directory))):
        directory = os.path.join(dataset_directory, str(i + 1))
        csv_file_path = os.path.join(directory, 'data_out.csv')
        
        # Check if the directory exists and data_out.csv does not exist
        if os.path.exists(directory) and (not os.path.exists(csv_file_path)):
            mat_file_path = os.path.join(directory, 'Vel.mat')

            # Check if the Vel.mat file exists in the directory
            if os.path.exists(mat_file_path):
                # Load the .mat file
                data = scipy.io.loadmat(mat_file_path)
                df = pd.DataFrame(data['V'], columns=['vx', 'vy', 'vz', 'omega_z'])

                # Save to CSV in the same directory
                df.to_csv(csv_file_path, index=False)

            else:
                print(f"'Vel.mat' file not found in {directory}")
        else:
            print(f"Directory {directory} does not exist or 'data_out.csv' already exists in directory {directory}")

# %%
# Directory containing the datasets
dataset_directory = 'quadrant_dataset' 

mat_to_csv(dataset_directory)
# Out:
# Directory quadrant_dataset/1 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/1
# Directory quadrant_dataset/2 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/2
# Directory quadrant_dataset/3 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/3
# Directory quadrant_dataset/4 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/4
# Directory quadrant_dataset/5 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/5
# Directory quadrant_dataset/6 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/6
# Directory quadrant_dataset/7 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/7
# Directory quadrant_dataset/8 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/8
# Directory quadrant_dataset/9 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/9
# Directory quadrant_dataset/10 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/10
# Directory quadrant_dataset/11 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/11
# Directory quadrant_dataset/12 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/12
# Directory quadrant_dataset/13 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/13
# Directory quadrant_dataset/14 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/14
# Directory quadrant_dataset/15 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/15
# Directory quadrant_dataset/16 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/16
# Directory quadrant_dataset/17 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/17
# Directory quadrant_dataset/18 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/18
# Directory quadrant_dataset/19 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/19
# Directory quadrant_dataset/20 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/20
# Directory quadrant_dataset/21 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/21
# Directory quadrant_dataset/22 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/22
# Directory quadrant_dataset/23 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/23
# Directory quadrant_dataset/24 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/24
# Directory quadrant_dataset/25 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/25
# Directory quadrant_dataset/26 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/26
# Directory quadrant_dataset/27 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/27
# Directory quadrant_dataset/28 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/28
# Directory quadrant_dataset/29 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/29
# Directory quadrant_dataset/30 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/30
# Directory quadrant_dataset/31 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/31
# Directory quadrant_dataset/32 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/32
# Directory quadrant_dataset/33 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/33
# Directory quadrant_dataset/34 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/34
# Directory quadrant_dataset/35 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/35
# Directory quadrant_dataset/36 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/36
# Directory quadrant_dataset/37 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/37
# Directory quadrant_dataset/38 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/38
# Directory quadrant_dataset/39 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/39
# Directory quadrant_dataset/40 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/40
# Directory quadrant_dataset/41 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/41
# Directory quadrant_dataset/42 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/42
# Directory quadrant_dataset/43 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/43
# Directory quadrant_dataset/44 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/44
# Directory quadrant_dataset/45 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/45
# Directory quadrant_dataset/46 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/46
# Directory quadrant_dataset/47 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/47
# Directory quadrant_dataset/48 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/48
# Directory quadrant_dataset/49 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/49
# Directory quadrant_dataset/50 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/50
# Directory quadrant_dataset/51 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/51
# Directory quadrant_dataset/52 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/52
# Directory quadrant_dataset/53 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/53
# Directory quadrant_dataset/54 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/54
# Directory quadrant_dataset/55 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/55
# Directory quadrant_dataset/56 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/56
# Directory quadrant_dataset/57 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/57
# Directory quadrant_dataset/58 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/58
# Directory quadrant_dataset/59 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/59
# Directory quadrant_dataset/60 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/60
# Directory quadrant_dataset/61 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/61
# Directory quadrant_dataset/62 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/62
# Directory quadrant_dataset/63 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/63
# Directory quadrant_dataset/64 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/64
# Directory quadrant_dataset/65 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/65
# Directory quadrant_dataset/66 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/66
# Directory quadrant_dataset/67 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/67
# Directory quadrant_dataset/68 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/68
# Directory quadrant_dataset/69 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/69
# Directory quadrant_dataset/70 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/70
# Directory quadrant_dataset/71 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/71
# Directory quadrant_dataset/72 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/72
# Directory quadrant_dataset/73 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/73
# Directory quadrant_dataset/74 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/74
# Directory quadrant_dataset/75 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/75
# Directory quadrant_dataset/76 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/76
# Directory quadrant_dataset/77 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/77
# Directory quadrant_dataset/78 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/78
# Directory quadrant_dataset/79 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/79
# Directory quadrant_dataset/80 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/80
# Directory quadrant_dataset/81 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/81
# Directory quadrant_dataset/82 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/82
# Directory quadrant_dataset/83 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/83
# Directory quadrant_dataset/84 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/84
# Directory quadrant_dataset/85 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/85
# Directory quadrant_dataset/86 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/86
# Directory quadrant_dataset/87 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/87
# Directory quadrant_dataset/88 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/88
# Directory quadrant_dataset/89 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/89
# Directory quadrant_dataset/90 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/90
# Directory quadrant_dataset/91 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/91
# Directory quadrant_dataset/92 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/92
# Directory quadrant_dataset/93 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/93
# Directory quadrant_dataset/94 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/94
# Directory quadrant_dataset/95 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/95
# Directory quadrant_dataset/96 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/96
# Directory quadrant_dataset/97 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/97
# Directory quadrant_dataset/98 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/98
# Directory quadrant_dataset/99 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/99
# Directory quadrant_dataset/100 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/100
# Directory quadrant_dataset/101 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/101
# Directory quadrant_dataset/102 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/102
# Directory quadrant_dataset/103 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/103
# Directory quadrant_dataset/104 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/104
# Directory quadrant_dataset/105 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/105
# Directory quadrant_dataset/106 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/106
# Directory quadrant_dataset/107 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/107
# Directory quadrant_dataset/108 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/108
# Directory quadrant_dataset/109 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/109
# Directory quadrant_dataset/110 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/110
# Directory quadrant_dataset/111 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/111
# Directory quadrant_dataset/112 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/112
# Directory quadrant_dataset/113 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/113
# Directory quadrant_dataset/114 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/114
# Directory quadrant_dataset/115 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/115
# Directory quadrant_dataset/116 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/116
# Directory quadrant_dataset/117 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/117
# Directory quadrant_dataset/118 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/118
# Directory quadrant_dataset/119 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/119
# Directory quadrant_dataset/120 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/120
# Directory quadrant_dataset/121 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/121
# Directory quadrant_dataset/122 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/122
# Directory quadrant_dataset/123 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/123
# Directory quadrant_dataset/124 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/124
# Directory quadrant_dataset/125 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/125
# Directory quadrant_dataset/126 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/126
# Directory quadrant_dataset/127 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/127
# Directory quadrant_dataset/128 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/128
# Directory quadrant_dataset/129 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/129
# Directory quadrant_dataset/130 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/130
# Directory quadrant_dataset/131 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/131
# Directory quadrant_dataset/132 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/132
# Directory quadrant_dataset/133 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/133
# Directory quadrant_dataset/134 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/134
# Directory quadrant_dataset/135 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/135
# Directory quadrant_dataset/136 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/136
# Directory quadrant_dataset/137 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/137
# Directory quadrant_dataset/138 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/138
# Directory quadrant_dataset/139 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/139
# Directory quadrant_dataset/140 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/140
# Directory quadrant_dataset/141 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/141
# Directory quadrant_dataset/142 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/142
# Directory quadrant_dataset/143 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/143
# Directory quadrant_dataset/144 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/144
# Directory quadrant_dataset/145 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/145
# Directory quadrant_dataset/146 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/146
# Directory quadrant_dataset/147 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/147
# Directory quadrant_dataset/148 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/148
# Directory quadrant_dataset/149 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/149
# Directory quadrant_dataset/150 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/150
# Directory quadrant_dataset/151 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/151
# Directory quadrant_dataset/152 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/152
# Directory quadrant_dataset/153 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/153
# Directory quadrant_dataset/154 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/154
# Directory quadrant_dataset/155 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/155
# Directory quadrant_dataset/156 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/156
# Directory quadrant_dataset/157 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/157
# Directory quadrant_dataset/158 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/158
# Directory quadrant_dataset/159 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/159
# Directory quadrant_dataset/160 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/160
# Directory quadrant_dataset/161 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/161
# Directory quadrant_dataset/162 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/162
# Directory quadrant_dataset/163 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/163
# Directory quadrant_dataset/164 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/164
# Directory quadrant_dataset/165 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/165
# Directory quadrant_dataset/166 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/166
# Directory quadrant_dataset/167 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/167
# Directory quadrant_dataset/168 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/168
# Directory quadrant_dataset/169 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/169
# Directory quadrant_dataset/170 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/170
# Directory quadrant_dataset/171 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/171
# Directory quadrant_dataset/172 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/172
# Directory quadrant_dataset/173 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/173
# Directory quadrant_dataset/174 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/174
# Directory quadrant_dataset/175 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/175
# Directory quadrant_dataset/176 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/176
# Directory quadrant_dataset/177 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/177
# Directory quadrant_dataset/178 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/178
# Directory quadrant_dataset/179 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/179
# Directory quadrant_dataset/180 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/180
# Directory quadrant_dataset/181 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/181
# Directory quadrant_dataset/182 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/182
# Directory quadrant_dataset/183 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/183
# Directory quadrant_dataset/184 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/184
# Directory quadrant_dataset/185 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/185
# Directory quadrant_dataset/186 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/186
# Directory quadrant_dataset/187 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/187
# Directory quadrant_dataset/188 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/188
# Directory quadrant_dataset/189 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/189
# Directory quadrant_dataset/190 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/190
# Directory quadrant_dataset/191 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/191
# Directory quadrant_dataset/192 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/192
# Directory quadrant_dataset/193 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/193
# Directory quadrant_dataset/194 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/194
# Directory quadrant_dataset/195 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/195
# Directory quadrant_dataset/196 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/196
# Directory quadrant_dataset/197 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/197
# Directory quadrant_dataset/198 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/198
# Directory quadrant_dataset/199 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/199
# Directory quadrant_dataset/200 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/200
# Directory quadrant_dataset/201 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/201
# Directory quadrant_dataset/202 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/202
# Directory quadrant_dataset/203 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/203
# Directory quadrant_dataset/204 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/204
# Directory quadrant_dataset/205 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/205
# Directory quadrant_dataset/206 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/206
# Directory quadrant_dataset/207 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/207
# Directory quadrant_dataset/208 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/208
# Directory quadrant_dataset/209 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/209
# Directory quadrant_dataset/210 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/210
# Directory quadrant_dataset/211 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/211
# Directory quadrant_dataset/212 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/212
# Directory quadrant_dataset/213 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/213
# Directory quadrant_dataset/214 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/214
# Directory quadrant_dataset/215 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/215
# Directory quadrant_dataset/216 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/216
# Directory quadrant_dataset/217 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/217
# Directory quadrant_dataset/218 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/218
# Directory quadrant_dataset/219 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/219
# Directory quadrant_dataset/220 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/220
# Directory quadrant_dataset/221 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/221
# Directory quadrant_dataset/222 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/222
# Directory quadrant_dataset/223 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/223
# Directory quadrant_dataset/224 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/224
# Directory quadrant_dataset/225 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/225
# Directory quadrant_dataset/226 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/226
# Directory quadrant_dataset/227 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/227
# Directory quadrant_dataset/228 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/228
# Directory quadrant_dataset/229 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/229
# Directory quadrant_dataset/230 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/230
# Directory quadrant_dataset/231 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/231
# Directory quadrant_dataset/232 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/232
# Directory quadrant_dataset/233 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/233
# Directory quadrant_dataset/234 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/234
# Directory quadrant_dataset/235 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/235
# Directory quadrant_dataset/236 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/236
# Directory quadrant_dataset/237 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/237
# Directory quadrant_dataset/238 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/238
# Directory quadrant_dataset/239 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/239
# Directory quadrant_dataset/240 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/240
# Directory quadrant_dataset/241 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/241
# Directory quadrant_dataset/242 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/242
# Directory quadrant_dataset/243 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/243
# Directory quadrant_dataset/244 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/244
# Directory quadrant_dataset/245 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/245
# Directory quadrant_dataset/246 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/246
# Directory quadrant_dataset/247 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/247
# Directory quadrant_dataset/248 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/248
# Directory quadrant_dataset/249 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/249
# Directory quadrant_dataset/250 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/250
# Directory quadrant_dataset/251 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/251
# Directory quadrant_dataset/252 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/252
# Directory quadrant_dataset/253 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/253
# Directory quadrant_dataset/254 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/254
# Directory quadrant_dataset/255 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/255
# Directory quadrant_dataset/256 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/256
# Directory quadrant_dataset/257 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/257
# Directory quadrant_dataset/258 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/258
# Directory quadrant_dataset/259 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/259
# Directory quadrant_dataset/260 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/260
# Directory quadrant_dataset/261 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/261
# Directory quadrant_dataset/262 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/262
# Directory quadrant_dataset/263 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/263
# Directory quadrant_dataset/264 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/264
# Directory quadrant_dataset/265 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/265
# Directory quadrant_dataset/266 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/266
# Directory quadrant_dataset/267 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/267
# Directory quadrant_dataset/268 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/268
# Directory quadrant_dataset/269 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/269
# Directory quadrant_dataset/270 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/270
# Directory quadrant_dataset/271 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/271
# Directory quadrant_dataset/272 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/272
# Directory quadrant_dataset/273 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/273
# Directory quadrant_dataset/274 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/274
# Directory quadrant_dataset/275 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/275
# Directory quadrant_dataset/276 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/276
# Directory quadrant_dataset/277 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/277
# Directory quadrant_dataset/278 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/278
# Directory quadrant_dataset/279 does not exist or 'data_out.csv' already exists in directory quadrant_dataset/279

# %%
# 30 % of each trajecrory as hovering 

root = "quadrant_dataset"
file_ending = 'png'
file_name = "data_out.csv"

for i in range(213, len(os.listdir(root))):
    directory = i + 1
    print("Processing directory", directory)

    csv_file_name = f"{root}/{str(directory)}/{file_name}"
    labels = np.genfromtxt(csv_file_name, delimiter=',', skip_header=1, dtype=np.float32)
    diff = int((30 * len(labels))/100)
    print("diff_labels", diff)
    print("labels len", labels.shape)
    
    velocity_values = [0.0, 0.0, 0.0, 0.0]
    
    with open(csv_file_name, 'a', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        for i in range(diff):
            csvwriter.writerow(velocity_values)
   

    n_images = len([fn for fn in os.listdir(f"./{root}/{str(directory)}") if file_ending in fn])
    print("Number of images:", n_images)
    
    img_file_name = f"{root}/{str(directory)}/Image{str(n_images)}.png"
    img = Image.open(img_file_name)
    for i in range(1, diff + 1):
       
        new_filename = os.path.join(root,str(directory))
        fname =  f"Image{str(i + n_images)}.png"
        file_path = os.path.join(new_filename, fname)
        
        img.save(file_path)
# Out:
# Processing directory 214
# diff_labels 147
# labels len (493, 4)
# Number of images: 493
# Processing directory 215
# diff_labels 129
# labels len (432, 4)
# Number of images: 432
# Processing directory 216
# diff_labels 149
# labels len (497, 4)
# Number of images: 497
# Processing directory 217
# diff_labels 63
# labels len (210, 4)
# Number of images: 210
# Processing directory 218
# diff_labels 102
# labels len (341, 4)
# Number of images: 341
# Processing directory 219
# diff_labels 147
# labels len (493, 4)
# Number of images: 493
# Processing directory 220
# diff_labels 102
# labels len (343, 4)
# Number of images: 343
# Processing directory 221
# diff_labels 130
# labels len (435, 4)
# Number of images: 435
# Processing directory 222
# diff_labels 100
# labels len (334, 4)
# Number of images: 334
# Processing directory 223
# diff_labels 149
# labels len (498, 4)
# Number of images: 498
# Processing directory 224
# diff_labels 62
# labels len (208, 4)
# Number of images: 208
# Processing directory 225
# diff_labels 148
# labels len (494, 4)
# Number of images: 494
# Processing directory 226
# diff_labels 123
# labels len (413, 4)
# Number of images: 413
# Processing directory 227
# diff_labels 148
# labels len (495, 4)
# Number of images: 495
# Processing directory 228
# diff_labels 129
# labels len (430, 4)
# Number of images: 430
# Processing directory 229
# diff_labels 106
# labels len (355, 4)
# Number of images: 355
# Processing directory 230
# diff_labels 101
# labels len (337, 4)
# Number of images: 337
# Processing directory 231
# diff_labels 117
# labels len (392, 4)
# Number of images: 392
# Processing directory 232
# diff_labels 148
# labels len (494, 4)
# Number of images: 494
# Processing directory 233
# diff_labels 128
# labels len (429, 4)
# Number of images: 429
# Processing directory 234
# diff_labels 129
# labels len (433, 4)
# Number of images: 433
# Processing directory 235
# diff_labels 148
# labels len (494, 4)
# Number of images: 494
# Processing directory 236
# diff_labels 128
# labels len (428, 4)
# Number of images: 428
# Processing directory 237
# diff_labels 148
# labels len (495, 4)
# Number of images: 495
# Processing directory 238
# diff_labels 129
# labels len (431, 4)
# Number of images: 431
# Processing directory 239
# diff_labels 129
# labels len (430, 4)
# Number of images: 430
# Processing directory 240
# diff_labels 148
# labels len (494, 4)
# Number of images: 494
# Processing directory 241
# diff_labels 148
# labels len (495, 4)
# Number of images: 495
# Processing directory 242
# diff_labels 120
# labels len (401, 4)
# Number of images: 401
# Processing directory 243
# diff_labels 128
# labels len (427, 4)
# Number of images: 427
# Processing directory 244
# diff_labels 147
# labels len (493, 4)
# Number of images: 493
# Processing directory 245
# diff_labels 109
# labels len (364, 4)
# Number of images: 364
# Processing directory 246
# diff_labels 66
# labels len (220, 4)
# Number of images: 220
# Processing directory 247
# diff_labels 148
# labels len (494, 4)
# Number of images: 494
# Processing directory 248
# diff_labels 148
# labels len (494, 4)
# Number of images: 494
# Processing directory 249
# diff_labels 119
# labels len (399, 4)
# Number of images: 399
# Processing directory 250
# diff_labels 148
# labels len (495, 4)
# Number of images: 495
# Processing directory 251
# diff_labels 90
# labels len (303, 4)
# Number of images: 303
# Processing directory 252
# diff_labels 147
# labels len (493, 4)
# Number of images: 493
# Processing directory 253
# diff_labels 147
# labels len (492, 4)
# Number of images: 492
# Processing directory 254
# diff_labels 128
# labels len (427, 4)
# Number of images: 427
# Processing directory 255
# diff_labels 67
# labels len (226, 4)
# Number of images: 226
# Processing directory 256
# diff_labels 101
# labels len (339, 4)
# Number of images: 339
# Processing directory 257
# diff_labels 128
# labels len (429, 4)
# Number of images: 429
# Processing directory 258
# diff_labels 100
# labels len (335, 4)
# Number of images: 335
# Processing directory 259
# diff_labels 101
# labels len (338, 4)
# Number of images: 338
# Processing directory 260
# diff_labels 148
# labels len (494, 4)
# Number of images: 494
# Processing directory 261
# diff_labels 127
# labels len (425, 4)
# Number of images: 425
# Processing directory 262
# diff_labels 148
# labels len (496, 4)
# Number of images: 496
# Processing directory 263
# diff_labels 148
# labels len (494, 4)
# Number of images: 494
# Processing directory 264
# diff_labels 129
# labels len (431, 4)
# Number of images: 431
# Processing directory 265
# diff_labels 101
# labels len (337, 4)
# Number of images: 337
# Processing directory 266
# diff_labels 148
# labels len (495, 4)
# Number of images: 495
# Processing directory 267
# diff_labels 147
# labels len (492, 4)
# Number of images: 492
# Processing directory 268
# diff_labels 92
# labels len (307, 4)
# Number of images: 307
# Processing directory 269
# diff_labels 102
# labels len (340, 4)
# Number of images: 340
# Processing directory 270
# diff_labels 127
# labels len (426, 4)
# Number of images: 426
# Processing directory 271
# diff_labels 121
# labels len (406, 4)
# Number of images: 406
# Processing directory 272
# diff_labels 147
# labels len (493, 4)
# Number of images: 493
# Processing directory 273
# diff_labels 102
# labels len (340, 4)
# Number of images: 340
# Processing directory 274
# diff_labels 103
# labels len (344, 4)
# Number of images: 344
# Processing directory 275
# diff_labels 100
# labels len (335, 4)
# Number of images: 335
# Processing directory 276
# diff_labels 148
# labels len (495, 4)
# Number of images: 495
# Processing directory 277
# diff_labels 101
# labels len (337, 4)
# Number of images: 337
# Processing directory 278
# diff_labels 101
# labels len (338, 4)
# Number of images: 338
# Processing directory 279
# diff_labels 128
# labels len (428, 4)
# Number of images: 428
# Processing directory 280
# diff_labels 148
# labels len (495, 4)
# Number of images: 495
# Processing directory 281
# diff_labels 68
# labels len (228, 4)
# Number of images: 228
# Processing directory 282
# diff_labels 99
# labels len (332, 4)
# Number of images: 332

# %%
# trajectory length as a factor of 64

root = "quadrant_dataset"
file_ending = 'png'
file_name = "data_out.csv"

for i in range(213, len(os.listdir(root))):
    directory = i + 1
    print("Processing directory", directory)

    csv_file_name = f"{root}/{str(directory)}/{file_name}"
    labels = np.genfromtxt(csv_file_name, delimiter=',', skip_header=1, dtype=np.float32)
    
    d = labels.shape[0]%64
    if d == 0:
        diff_labels = 0
    else:
        diff_labels = 64 - d
 
    # print("labels", labels[-1])
    velocity_values = [0.0, 0.0, 0.0, 0.0]
    
    with open(csv_file_name, 'a', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        for i in range(diff_labels):
            csvwriter.writerow(velocity_values)
   

   
    n_images = len([fn for fn in os.listdir(f"./{root}/{str(directory)}") if file_ending in fn])
    print("Number of images:", n_images)
  
    d_img = n_images % 64
    
    if d_img == 0:
        diff = 0
    else:
        diff = 64 - d_img
    print("diff_labels", diff_labels, " diff", diff, " diff_labels%64", (labels.shape[0] + diff_labels)%64, " diff%64", (n_images + diff)%64)
    
    img_file_name = f"{root}/{str(directory)}/Image{str(n_images)}.png"
    img = Image.open(img_file_name)
    for i in range(1, diff + 1):
       
        new_filename = os.path.join(root,str(directory))
        fname =  f"Image{str(i + n_images)}.png"
        file_path = os.path.join(new_filename, fname)
        
        img.save(file_path)
# Out:
# Processing directory 214
# Number of images: 640
# diff_labels 0  diff 0  diff_labels%64 0  diff%64 0
# Processing directory 215
# Number of images: 561
# diff_labels 15  diff 15  diff_labels%64 0  diff%64 0
# Processing directory 216
# Number of images: 646
# diff_labels 58  diff 58  diff_labels%64 0  diff%64 0
# Processing directory 217
# Number of images: 273
# diff_labels 47  diff 47  diff_labels%64 0  diff%64 0
# Processing directory 218
# Number of images: 443
# diff_labels 5  diff 5  diff_labels%64 0  diff%64 0
# Processing directory 219
# Number of images: 640
# diff_labels 0  diff 0  diff_labels%64 0  diff%64 0
# Processing directory 220
# Number of images: 445
# diff_labels 3  diff 3  diff_labels%64 0  diff%64 0
# Processing directory 221
# Number of images: 565
# diff_labels 11  diff 11  diff_labels%64 0  diff%64 0
# Processing directory 222
# Number of images: 434
# diff_labels 14  diff 14  diff_labels%64 0  diff%64 0
# Processing directory 223
# Number of images: 647
# diff_labels 57  diff 57  diff_labels%64 0  diff%64 0
# Processing directory 224
# Number of images: 270
# diff_labels 50  diff 50  diff_labels%64 0  diff%64 0
# Processing directory 225
# Number of images: 642
# diff_labels 62  diff 62  diff_labels%64 0  diff%64 0
# Processing directory 226
# Number of images: 536
# diff_labels 40  diff 40  diff_labels%64 0  diff%64 0
# Processing directory 227
# Number of images: 643
# diff_labels 61  diff 61  diff_labels%64 0  diff%64 0
# Processing directory 228
# Number of images: 559
# diff_labels 17  diff 17  diff_labels%64 0  diff%64 0
# Processing directory 229
# Number of images: 461
# diff_labels 51  diff 51  diff_labels%64 0  diff%64 0
# Processing directory 230
# Number of images: 438
# diff_labels 10  diff 10  diff_labels%64 0  diff%64 0
# Processing directory 231
# Number of images: 509
# diff_labels 3  diff 3  diff_labels%64 0  diff%64 0
# Processing directory 232
# Number of images: 642
# diff_labels 62  diff 62  diff_labels%64 0  diff%64 0
# Processing directory 233
# Number of images: 557
# diff_labels 19  diff 19  diff_labels%64 0  diff%64 0
# Processing directory 234
# Number of images: 562
# diff_labels 14  diff 14  diff_labels%64 0  diff%64 0
# Processing directory 235
# Number of images: 642
# diff_labels 62  diff 62  diff_labels%64 0  diff%64 0
# Processing directory 236
# Number of images: 556
# diff_labels 20  diff 20  diff_labels%64 0  diff%64 0
# Processing directory 237
# Number of images: 643
# diff_labels 61  diff 61  diff_labels%64 0  diff%64 0
# Processing directory 238
# Number of images: 560
# diff_labels 16  diff 16  diff_labels%64 0  diff%64 0
# Processing directory 239
# Number of images: 559
# diff_labels 17  diff 17  diff_labels%64 0  diff%64 0
# Processing directory 240
# Number of images: 642
# diff_labels 62  diff 62  diff_labels%64 0  diff%64 0
# Processing directory 241
# Number of images: 643
# diff_labels 61  diff 61  diff_labels%64 0  diff%64 0
# Processing directory 242
# Number of images: 521
# diff_labels 55  diff 55  diff_labels%64 0  diff%64 0
# Processing directory 243
# Number of images: 555
# diff_labels 21  diff 21  diff_labels%64 0  diff%64 0
# Processing directory 244
# Number of images: 640
# diff_labels 0  diff 0  diff_labels%64 0  diff%64 0
# Processing directory 245
# Number of images: 473
# diff_labels 39  diff 39  diff_labels%64 0  diff%64 0
# Processing directory 246
# Number of images: 286
# diff_labels 34  diff 34  diff_labels%64 0  diff%64 0
# Processing directory 247
# Number of images: 642
# diff_labels 62  diff 62  diff_labels%64 0  diff%64 0
# Processing directory 248
# Number of images: 642
# diff_labels 62  diff 62  diff_labels%64 0  diff%64 0
# Processing directory 249
# Number of images: 518
# diff_labels 58  diff 58  diff_labels%64 0  diff%64 0
# Processing directory 250
# Number of images: 643
# diff_labels 61  diff 61  diff_labels%64 0  diff%64 0
# Processing directory 251
# Number of images: 393
# diff_labels 55  diff 55  diff_labels%64 0  diff%64 0
# Processing directory 252
# Number of images: 640
# diff_labels 0  diff 0  diff_labels%64 0  diff%64 0
# Processing directory 253
# Number of images: 639
# diff_labels 1  diff 1  diff_labels%64 0  diff%64 0
# Processing directory 254
# Number of images: 555
# diff_labels 21  diff 21  diff_labels%64 0  diff%64 0
# Processing directory 255
# Number of images: 293
# diff_labels 27  diff 27  diff_labels%64 0  diff%64 0
# Processing directory 256
# Number of images: 440
# diff_labels 8  diff 8  diff_labels%64 0  diff%64 0
# Processing directory 257
# Number of images: 557
# diff_labels 19  diff 19  diff_labels%64 0  diff%64 0
# Processing directory 258
# Number of images: 435
# diff_labels 13  diff 13  diff_labels%64 0  diff%64 0
# Processing directory 259
# Number of images: 439
# diff_labels 9  diff 9  diff_labels%64 0  diff%64 0
# Processing directory 260
# Number of images: 642
# diff_labels 62  diff 62  diff_labels%64 0  diff%64 0
# Processing directory 261
# Number of images: 552
# diff_labels 24  diff 24  diff_labels%64 0  diff%64 0
# Processing directory 262
# Number of images: 644
# diff_labels 60  diff 60  diff_labels%64 0  diff%64 0
# Processing directory 263
# Number of images: 642
# diff_labels 62  diff 62  diff_labels%64 0  diff%64 0
# Processing directory 264
# Number of images: 560
# diff_labels 16  diff 16  diff_labels%64 0  diff%64 0
# Processing directory 265
# Number of images: 438
# diff_labels 10  diff 10  diff_labels%64 0  diff%64 0
# Processing directory 266
# Number of images: 643
# diff_labels 61  diff 61  diff_labels%64 0  diff%64 0
# Processing directory 267
# Number of images: 639
# diff_labels 1  diff 1  diff_labels%64 0  diff%64 0
# Processing directory 268
# Number of images: 399
# diff_labels 49  diff 49  diff_labels%64 0  diff%64 0
# Processing directory 269
# Number of images: 442
# diff_labels 6  diff 6  diff_labels%64 0  diff%64 0
# Processing directory 270
# Number of images: 553
# diff_labels 23  diff 23  diff_labels%64 0  diff%64 0
# Processing directory 271
# Number of images: 527
# diff_labels 49  diff 49  diff_labels%64 0  diff%64 0
# Processing directory 272
# Number of images: 640
# diff_labels 0  diff 0  diff_labels%64 0  diff%64 0
# Processing directory 273
# Number of images: 442
# diff_labels 6  diff 6  diff_labels%64 0  diff%64 0
# Processing directory 274
# Number of images: 447
# diff_labels 1  diff 1  diff_labels%64 0  diff%64 0
# Processing directory 275
# Number of images: 435
# diff_labels 13  diff 13  diff_labels%64 0  diff%64 0
# Processing directory 276
# Number of images: 643
# diff_labels 61  diff 61  diff_labels%64 0  diff%64 0
# Processing directory 277
# Number of images: 438
# diff_labels 10  diff 10  diff_labels%64 0  diff%64 0
# Processing directory 278
# Number of images: 439
# diff_labels 9  diff 9  diff_labels%64 0  diff%64 0
# Processing directory 279
# Number of images: 556
# diff_labels 20  diff 20  diff_labels%64 0  diff%64 0
# Processing directory 280
# Number of images: 643
# diff_labels 61  diff 61  diff_labels%64 0  diff%64 0
# Processing directory 281
# Number of images: 296
# diff_labels 24  diff 24  diff_labels%64 0  diff%64 0
# Processing directory 282
# Number of images: 431
# diff_labels 17  diff 17  diff_labels%64 0  diff%64 0

# %%
# Creating sparse subset of the trajectory
root = "quadrant_dataset"
file_ending = 'png'
file_name = "data_out.csv"
length_root = len(os.listdir(root))

for i in range(len(os.listdir(root))):
    directory = i + 1
    print("Processing directory", directory)
    new_directory = length_root + directory
    print("Creating directory", new_directory)
    new_directory_path = f"{root}/{new_directory}"
    if not os.path.exists(new_directory_path):
        os.makedirs(new_directory_path)
        
   
    csv_file_name = f"{root}/{str(directory)}/{file_name}"
    labels = np.genfromtxt(csv_file_name, delimiter=',', skip_header=1, dtype=np.float32)

    image_files = [fn for fn in os.listdir(f"./{root}/{str(directory)}") if file_ending in fn]
    n_images = len(image_files)
    print("Number of images:", n_images)
    sorted_image_files = list(range(1, n_images + 1))

    # Select every 10th image
    selected_images_files = sorted_image_files[::10]
    selected_images_files = selected_images_files[:44]
    selected_images_files.extend([n_images] * 20)

    selected_labels = labels[::10].tolist()  
    selected_labels = selected_labels[:44]
    
    # print(len(selected_images_files), len(selected_labels))
    
    # last image
    
    velocity_values = [0.0, 0.0, 0.0, 0.0]
    selected_labels.extend([velocity_values] * 20)
    
    # print(selected_images_files, selected_labels)

    for i in range(len(selected_images_files)):
        image_file = selected_images_files[i]
        image_path = f"{root}/{str(directory)}/Image{str(image_file)}.png"
        img = Image.open(image_path)
       
        new_filename =  f"{root}/{new_directory}/Image{str(i + 1)}.png"
       
        img.save(new_filename)
    
    columns = ['vx', 'vy', 'vz', 'omega_z']
    df = pd.DataFrame(selected_labels, columns=columns)
    df.to_csv(f"{root}/{new_directory}/{file_name}", index=False)
# Out:
# Processing directory 1
# Creating directory 283
# Number of images: 640
# Processing directory 2
# Creating directory 284
# Number of images: 832
# Processing directory 3
# Creating directory 285
# Number of images: 768
# Processing directory 4
# Creating directory 286
# Number of images: 704
# Processing directory 5
# Creating directory 287
# Number of images: 1152
# Processing directory 6
# Creating directory 288
# Number of images: 640
# Processing directory 7
# Creating directory 289
# Number of images: 704
# Processing directory 8
# Creating directory 290
# Number of images: 1024
# Processing directory 9
# Creating directory 291
# Number of images: 704
# Processing directory 10
# Creating directory 292
# Number of images: 832
# Processing directory 11
# Creating directory 293
# Number of images: 960
# Processing directory 12
# Creating directory 294
# Number of images: 704
# Processing directory 13
# Creating directory 295
# Number of images: 576
# Processing directory 14
# Creating directory 296
# Number of images: 832
# Processing directory 15
# Creating directory 297
# Number of images: 640
# Processing directory 16
# Creating directory 298
# Number of images: 640
# Processing directory 17
# Creating directory 299
# Number of images: 768
# Processing directory 18
# Creating directory 300
# Number of images: 896
# Processing directory 19
# Creating directory 301
# Number of images: 640
# Processing directory 20
# Creating directory 302
# Number of images: 896
# Processing directory 21
# Creating directory 303
# Number of images: 896
# Processing directory 22
# Creating directory 304
# Number of images: 704
# Processing directory 23
# Creating directory 305
# Number of images: 640
# Processing directory 24
# Creating directory 306
# Number of images: 832
# Processing directory 25
# Creating directory 307
# Number of images: 768
# Processing directory 26
# Creating directory 308
# Number of images: 704
# Processing directory 27
# Creating directory 309
# Number of images: 768
# Processing directory 28
# Creating directory 310
# Number of images: 832
# Processing directory 29
# Creating directory 311
# Number of images: 832
# Processing directory 30
# Creating directory 312
# Number of images: 704
# Processing directory 31
# Creating directory 313
# Number of images: 832
# Processing directory 32
# Creating directory 314
# Number of images: 832
# Processing directory 33
# Creating directory 315
# Number of images: 896
# Processing directory 34
# Creating directory 316
# Number of images: 832
# Processing directory 35
# Creating directory 317
# Number of images: 704
# Processing directory 36
# Creating directory 318
# Number of images: 704
# Processing directory 37
# Creating directory 319
# Number of images: 640
# Processing directory 38
# Creating directory 320
# Number of images: 576
# Processing directory 39
# Creating directory 321
# Number of images: 704
# Processing directory 40
# Creating directory 322
# Number of images: 768
# Processing directory 41
# Creating directory 323
# Number of images: 512
# Processing directory 42
# Creating directory 324
# Number of images: 768
# Processing directory 43
# Creating directory 325
# Number of images: 576
# Processing directory 44
# Creating directory 326
# Number of images: 704
# Processing directory 45
# Creating directory 327
# Number of images: 768
# Processing directory 46
# Creating directory 328
# Number of images: 704
# Processing directory 47
# Creating directory 329
# Number of images: 768
# Processing directory 48
# Creating directory 330
# Number of images: 704
# Processing directory 49
# Creating directory 331
# Number of images: 832
# Processing directory 50
# Creating directory 332
# Number of images: 576
# Processing directory 51
# Creating directory 333
# Number of images: 768
# Processing directory 52
# Creating directory 334
# Number of images: 768
# Processing directory 53
# Creating directory 335
# Number of images: 768
# Processing directory 54
# Creating directory 336
# Number of images: 832
# Processing directory 55
# Creating directory 337
# Number of images: 640
# Processing directory 56
# Creating directory 338
# Number of images: 704
# Processing directory 57
# Creating directory 339
# Number of images: 704
# Processing directory 58
# Creating directory 340
# Number of images: 640
# Processing directory 59
# Creating directory 341
# Number of images: 832
# Processing directory 60
# Creating directory 342
# Number of images: 704
# Processing directory 61
# Creating directory 343
# Number of images: 896
# Processing directory 62
# Creating directory 344
# Number of images: 704
# Processing directory 63
# Creating directory 345
# Number of images: 704
# Processing directory 64
# Creating directory 346
# Number of images: 576
# Processing directory 65
# Creating directory 347
# Number of images: 704
# Processing directory 66
# Creating directory 348
# Number of images: 960
# Processing directory 67
# Creating directory 349
# Number of images: 640
# Processing directory 68
# Creating directory 350
# Number of images: 512
# Processing directory 69
# Creating directory 351
# Number of images: 576
# Processing directory 70
# Creating directory 352
# Number of images: 640
# Processing directory 71
# Creating directory 353
# Number of images: 640
# Processing directory 72
# Creating directory 354
# Number of images: 448
# Processing directory 73
# Creating directory 355
# Number of images: 576
# Processing directory 74
# Creating directory 356
# Number of images: 576
# Processing directory 75
# Creating directory 357
# Number of images: 576
# Processing directory 76
# Creating directory 358
# Number of images: 448
# Processing directory 77
# Creating directory 359
# Number of images: 640
# Processing directory 78
# Creating directory 360
# Number of images: 448
# Processing directory 79
# Creating directory 361
# Number of images: 640
# Processing directory 80
# Creating directory 362
# Number of images: 576
# Processing directory 81
# Creating directory 363
# Number of images: 448
# Processing directory 82
# Creating directory 364
# Number of images: 704
# Processing directory 83
# Creating directory 365
# Number of images: 704
# Processing directory 84
# Creating directory 366
# Number of images: 512
# Processing directory 85
# Creating directory 367
# Number of images: 576
# Processing directory 86
# Creating directory 368
# Number of images: 576
# Processing directory 87
# Creating directory 369
# Number of images: 576
# Processing directory 88
# Creating directory 370
# Number of images: 576
# Processing directory 89
# Creating directory 371
# Number of images: 704
# Processing directory 90
# Creating directory 372
# Number of images: 576
# Processing directory 91
# Creating directory 373
# Number of images: 704
# Processing directory 92
# Creating directory 374
# Number of images: 704
# Processing directory 93
# Creating directory 375
# Number of images: 704
# Processing directory 94
# Creating directory 376
# Number of images: 576
# Processing directory 95
# Creating directory 377
# Number of images: 512
# Processing directory 96
# Creating directory 378
# Number of images: 704
# Processing directory 97
# Creating directory 379
# Number of images: 448
# Processing directory 98
# Creating directory 380
# Number of images: 640
# Processing directory 99
# Creating directory 381
# Number of images: 704
# Processing directory 100
# Creating directory 382
# Number of images: 704
# Processing directory 101
# Creating directory 383
# Number of images: 640
# Processing directory 102
# Creating directory 384
# Number of images: 704
# Processing directory 103
# Creating directory 385
# Number of images: 448
# Processing directory 104
# Creating directory 386
# Number of images: 704
# Processing directory 105
# Creating directory 387
# Number of images: 704
# Processing directory 106
# Creating directory 388
# Number of images: 576
# Processing directory 107
# Creating directory 389
# Number of images: 448
# Processing directory 108
# Creating directory 390
# Number of images: 704
# Processing directory 109
# Creating directory 391
# Number of images: 576
# Processing directory 110
# Creating directory 392
# Number of images: 448
# Processing directory 111
# Creating directory 393
# Number of images: 704
# Processing directory 112
# Creating directory 394
# Number of images: 576
# Processing directory 113
# Creating directory 395
# Number of images: 640
# Processing directory 114
# Creating directory 396
# Number of images: 576
# Processing directory 115
# Creating directory 397
# Number of images: 704
# Processing directory 116
# Creating directory 398
# Number of images: 576
# Processing directory 117
# Creating directory 399
# Number of images: 576
# Processing directory 118
# Creating directory 400
# Number of images: 704
# Processing directory 119
# Creating directory 401
# Number of images: 576
# Processing directory 120
# Creating directory 402
# Number of images: 704
# Processing directory 121
# Creating directory 403
# Number of images: 448
# Processing directory 122
# Creating directory 404
# Number of images: 704
# Processing directory 123
# Creating directory 405
# Number of images: 576
# Processing directory 124
# Creating directory 406
# Number of images: 448
# Processing directory 125
# Creating directory 407
# Number of images: 576
# Processing directory 126
# Creating directory 408
# Number of images: 448
# Processing directory 127
# Creating directory 409
# Number of images: 448
# Processing directory 128
# Creating directory 410
# Number of images: 512
# Processing directory 129
# Creating directory 411
# Number of images: 448
# Processing directory 130
# Creating directory 412
# Number of images: 448
# Processing directory 131
# Creating directory 413
# Number of images: 320
# Processing directory 132
# Creating directory 414
# Number of images: 512
# Processing directory 133
# Creating directory 415
# Number of images: 448
# Processing directory 134
# Creating directory 416
# Number of images: 320
# Processing directory 135
# Creating directory 417
# Number of images: 448
# Processing directory 136
# Creating directory 418
# Number of images: 320
# Processing directory 137
# Creating directory 419
# Number of images: 320
# Processing directory 138
# Creating directory 420
# Number of images: 448
# Processing directory 139
# Creating directory 421
# Number of images: 448
# Processing directory 140
# Creating directory 422
# Number of images: 448
# Processing directory 141
# Creating directory 423
# Number of images: 640
# Processing directory 142
# Creating directory 424
# Number of images: 640
# Processing directory 143
# Creating directory 425
# Number of images: 704
# Processing directory 144
# Creating directory 426
# Number of images: 448
# Processing directory 145
# Creating directory 427
# Number of images: 576
# Processing directory 146
# Creating directory 428
# Number of images: 512
# Processing directory 147
# Creating directory 429
# Number of images: 576
# Processing directory 148
# Creating directory 430
# Number of images: 320
# Processing directory 149
# Creating directory 431
# Number of images: 704
# Processing directory 150
# Creating directory 432
# Number of images: 320
# Processing directory 151
# Creating directory 433
# Number of images: 448
# Processing directory 152
# Creating directory 434
# Number of images: 448
# Processing directory 153
# Creating directory 435
# Number of images: 448
# Processing directory 154
# Creating directory 436
# Number of images: 512
# Processing directory 155
# Creating directory 437
# Number of images: 704
# Processing directory 156
# Creating directory 438
# Number of images: 704
# Processing directory 157
# Creating directory 439
# Number of images: 704
# Processing directory 158
# Creating directory 440
# Number of images: 640
# Processing directory 159
# Creating directory 441
# Number of images: 448
# Processing directory 160
# Creating directory 442
# Number of images: 704
# Processing directory 161
# Creating directory 443
# Number of images: 704
# Processing directory 162
# Creating directory 444
# Number of images: 576
# Processing directory 163
# Creating directory 445
# Number of images: 512
# Processing directory 164
# Creating directory 446
# Number of images: 704
# Processing directory 165
# Creating directory 447
# Number of images: 448
# Processing directory 166
# Creating directory 448
# Number of images: 576
# Processing directory 167
# Creating directory 449
# Number of images: 704
# Processing directory 168
# Creating directory 450
# Number of images: 448
# Processing directory 169
# Creating directory 451
# Number of images: 576
# Processing directory 170
# Creating directory 452
# Number of images: 448
# Processing directory 171
# Creating directory 453
# Number of images: 320
# Processing directory 172
# Creating directory 454
# Number of images: 448
# Processing directory 173
# Creating directory 455
# Number of images: 640
# Processing directory 174
# Creating directory 456
# Number of images: 576
# Processing directory 175
# Creating directory 457
# Number of images: 512
# Processing directory 176
# Creating directory 458
# Number of images: 576
# Processing directory 177
# Creating directory 459
# Number of images: 512
# Processing directory 178
# Creating directory 460
# Number of images: 512
# Processing directory 179
# Creating directory 461
# Number of images: 640
# Processing directory 180
# Creating directory 462
# Number of images: 704
# Processing directory 181
# Creating directory 463
# Number of images: 320
# Processing directory 182
# Creating directory 464
# Number of images: 448
# Processing directory 183
# Creating directory 465
# Number of images: 704
# Processing directory 184
# Creating directory 466
# Number of images: 448
# Processing directory 185
# Creating directory 467
# Number of images: 512
# Processing directory 186
# Creating directory 468
# Number of images: 320
# Processing directory 187
# Creating directory 469
# Number of images: 448
# Processing directory 188
# Creating directory 470
# Number of images: 704
# Processing directory 189
# Creating directory 471
# Number of images: 512
# Processing directory 190
# Creating directory 472
# Number of images: 704
# Processing directory 191
# Creating directory 473
# Number of images: 704
# Processing directory 192
# Creating directory 474
# Number of images: 448
# Processing directory 193
# Creating directory 475
# Number of images: 448
# Processing directory 194
# Creating directory 476
# Number of images: 320
# Processing directory 195
# Creating directory 477
# Number of images: 448
# Processing directory 196
# Creating directory 478
# Number of images: 448
# Processing directory 197
# Creating directory 479
# Number of images: 640
# Processing directory 198
# Creating directory 480
# Number of images: 576
# Processing directory 199
# Creating directory 481
# Number of images: 448
# Processing directory 200
# Creating directory 482
# Number of images: 448
# Processing directory 201
# Creating directory 483
# Number of images: 704
# Processing directory 202
# Creating directory 484
# Number of images: 576
# Processing directory 203
# Creating directory 485
# Number of images: 704
# Processing directory 204
# Creating directory 486
# Number of images: 512
# Processing directory 205
# Creating directory 487
# Number of images: 576
# Processing directory 206
# Creating directory 488
# Number of images: 704
# Processing directory 207
# Creating directory 489
# Number of images: 576
# Processing directory 208
# Creating directory 490
# Number of images: 640
# Processing directory 209
# Creating directory 491
# Number of images: 576
# Processing directory 210
# Creating directory 492
# Number of images: 576
# Processing directory 211
# Creating directory 493
# Number of images: 448
# Processing directory 212
# Creating directory 494
# Number of images: 576
# Processing directory 213
# Creating directory 495
# Number of images: 576
# Processing directory 214
# Creating directory 496
# Number of images: 640
# Processing directory 215
# Creating directory 497
# Number of images: 576
# Processing directory 216
# Creating directory 498
# Number of images: 704
# Processing directory 217
# Creating directory 499
# Number of images: 320
# Processing directory 218
# Creating directory 500
# Number of images: 448
# Processing directory 219
# Creating directory 501
# Number of images: 640
# Processing directory 220
# Creating directory 502
# Number of images: 448
# Processing directory 221
# Creating directory 503
# Number of images: 576
# Processing directory 222
# Creating directory 504
# Number of images: 448
# Processing directory 223
# Creating directory 505
# Number of images: 704
# Processing directory 224
# Creating directory 506
# Number of images: 320
# Processing directory 225
# Creating directory 507
# Number of images: 704
# Processing directory 226
# Creating directory 508
# Number of images: 576
# Processing directory 227
# Creating directory 509
# Number of images: 704
# Processing directory 228
# Creating directory 510
# Number of images: 576
# Processing directory 229
# Creating directory 511
# Number of images: 512
# Processing directory 230
# Creating directory 512
# Number of images: 448
# Processing directory 231
# Creating directory 513
# Number of images: 512
# Processing directory 232
# Creating directory 514
# Number of images: 704
# Processing directory 233
# Creating directory 515
# Number of images: 576
# Processing directory 234
# Creating directory 516
# Number of images: 576
# Processing directory 235
# Creating directory 517
# Number of images: 704
# Processing directory 236
# Creating directory 518
# Number of images: 576
# Processing directory 237
# Creating directory 519
# Number of images: 704
# Processing directory 238
# Creating directory 520
# Number of images: 576
# Processing directory 239
# Creating directory 521
# Number of images: 576
# Processing directory 240
# Creating directory 522
# Number of images: 704
# Processing directory 241
# Creating directory 523
# Number of images: 704
# Processing directory 242
# Creating directory 524
# Number of images: 576
# Processing directory 243
# Creating directory 525
# Number of images: 576
# Processing directory 244
# Creating directory 526
# Number of images: 640
# Processing directory 245
# Creating directory 527
# Number of images: 512
# Processing directory 246
# Creating directory 528
# Number of images: 320
# Processing directory 247
# Creating directory 529
# Number of images: 704
# Processing directory 248
# Creating directory 530
# Number of images: 704
# Processing directory 249
# Creating directory 531
# Number of images: 576
# Processing directory 250
# Creating directory 532
# Number of images: 704
# Processing directory 251
# Creating directory 533
# Number of images: 448
# Processing directory 252
# Creating directory 534
# Number of images: 640
# Processing directory 253
# Creating directory 535
# Number of images: 640
# Processing directory 254
# Creating directory 536
# Number of images: 576
# Processing directory 255
# Creating directory 537
# Number of images: 320
# Processing directory 256
# Creating directory 538
# Number of images: 448
# Processing directory 257
# Creating directory 539
# Number of images: 576
# Processing directory 258
# Creating directory 540
# Number of images: 448
# Processing directory 259
# Creating directory 541
# Number of images: 448
# Processing directory 260
# Creating directory 542
# Number of images: 704
# Processing directory 261
# Creating directory 543
# Number of images: 576
# Processing directory 262
# Creating directory 544
# Number of images: 704
# Processing directory 263
# Creating directory 545
# Number of images: 704
# Processing directory 264
# Creating directory 546
# Number of images: 576
# Processing directory 265
# Creating directory 547
# Number of images: 448
# Processing directory 266
# Creating directory 548
# Number of images: 704
# Processing directory 267
# Creating directory 549
# Number of images: 640
# Processing directory 268
# Creating directory 550
# Number of images: 448
# Processing directory 269
# Creating directory 551
# Number of images: 448
# Processing directory 270
# Creating directory 552
# Number of images: 576
# Processing directory 271
# Creating directory 553
# Number of images: 576
# Processing directory 272
# Creating directory 554
# Number of images: 640
# Processing directory 273
# Creating directory 555
# Number of images: 448
# Processing directory 274
# Creating directory 556
# Number of images: 448
# Processing directory 275
# Creating directory 557
# Number of images: 448
# Processing directory 276
# Creating directory 558
# Number of images: 704
# Processing directory 277
# Creating directory 559
# Number of images: 448
# Processing directory 278
# Creating directory 560
# Number of images: 448
# Processing directory 279
# Creating directory 561
# Number of images: 576
# Processing directory 280
# Creating directory 562
# Number of images: 704
# Processing directory 281
# Creating directory 563
# Number of images: 320
# Processing directory 282
# Creating directory 564
# Number of images: 448

# %%
# Checking if the dataset has no of velocity and images same

root = "quadrant_dataset"
file_ending = 'png'
file_name = "data_out.csv"

for i in range(len(os.listdir(root))):
    try:
        directory = i + 1
        print("Processing directory", directory)

        csv_file_name = f"{root}/{str(directory)}/{file_name}"
        labels = np.genfromtxt(csv_file_name, delimiter=',', skip_header=1, dtype=np.float32)
        

        image_files = [fn for fn in os.listdir(f"./{root}/{str(directory)}") if file_ending in fn]
        n_images = len(image_files)
        print(f"Number of labels: {len(labels)} Number of images: {n_images}")

        assert len(labels) == n_images and n_images >= 64, f"{directory}"
    except:
        pass
# Out:
# Processing directory 1
# Number of labels: 640 Number of images: 640
# Processing directory 2
# Number of labels: 832 Number of images: 832
# Processing directory 3
# Number of labels: 768 Number of images: 768
# Processing directory 4
# Number of labels: 704 Number of images: 704
# Processing directory 5
# Number of labels: 1152 Number of images: 1152
# Processing directory 6
# Number of labels: 640 Number of images: 640
# Processing directory 7
# Number of labels: 704 Number of images: 704
# Processing directory 8
# Number of labels: 1024 Number of images: 1024
# Processing directory 9
# Number of labels: 704 Number of images: 704
# Processing directory 10
# Number of labels: 832 Number of images: 832
# Processing directory 11
# Number of labels: 960 Number of images: 960
# Processing directory 12
# Number of labels: 704 Number of images: 704
# Processing directory 13
# Number of labels: 576 Number of images: 576
# Processing directory 14
# Number of labels: 832 Number of images: 832
# Processing directory 15
# Number of labels: 640 Number of images: 640
# Processing directory 16
# Number of labels: 640 Number of images: 640
# Processing directory 17
# Number of labels: 768 Number of images: 768
# Processing directory 18
# Number of labels: 896 Number of images: 896
# Processing directory 19
# Number of labels: 640 Number of images: 640
# Processing directory 20
# Number of labels: 896 Number of images: 896
# Processing directory 21
# Number of labels: 896 Number of images: 896
# Processing directory 22
# Number of labels: 704 Number of images: 704
# Processing directory 23
# Number of labels: 640 Number of images: 640
# Processing directory 24
# Number of labels: 832 Number of images: 832
# Processing directory 25
# Number of labels: 768 Number of images: 768
# Processing directory 26
# Number of labels: 704 Number of images: 704
# Processing directory 27
# Number of labels: 768 Number of images: 768
# Processing directory 28
# Number of labels: 832 Number of images: 832
# Processing directory 29
# Number of labels: 832 Number of images: 832
# Processing directory 30
# Number of labels: 704 Number of images: 704
# Processing directory 31
# Number of labels: 832 Number of images: 832
# Processing directory 32
# Number of labels: 832 Number of images: 832
# Processing directory 33
# Number of labels: 896 Number of images: 896
# Processing directory 34
# Number of labels: 832 Number of images: 832
# Processing directory 35
# Number of labels: 704 Number of images: 704
# Processing directory 36
# Number of labels: 704 Number of images: 704
# Processing directory 37
# Number of labels: 640 Number of images: 640
# Processing directory 38
# Number of labels: 576 Number of images: 576
# Processing directory 39
# Number of labels: 704 Number of images: 704
# Processing directory 40
# Number of labels: 768 Number of images: 768
# Processing directory 41
# Number of labels: 512 Number of images: 512
# Processing directory 42
# Number of labels: 768 Number of images: 768
# Processing directory 43
# Number of labels: 576 Number of images: 576
# Processing directory 44
# Number of labels: 704 Number of images: 704
# Processing directory 45
# Number of labels: 768 Number of images: 768
# Processing directory 46
# Number of labels: 704 Number of images: 704
# Processing directory 47
# Number of labels: 768 Number of images: 768
# Processing directory 48
# Number of labels: 704 Number of images: 704
# Processing directory 49
# Number of labels: 832 Number of images: 832
# Processing directory 50
# Number of labels: 576 Number of images: 576
# Processing directory 51
# Number of labels: 768 Number of images: 768
# Processing directory 52
# Number of labels: 768 Number of images: 768
# Processing directory 53
# Number of labels: 768 Number of images: 768
# Processing directory 54
# Number of labels: 832 Number of images: 832
# Processing directory 55
# Number of labels: 640 Number of images: 640
# Processing directory 56
# Number of labels: 704 Number of images: 704
# Processing directory 57
# Number of labels: 704 Number of images: 704
# Processing directory 58
# Number of labels: 640 Number of images: 640
# Processing directory 59
# Number of labels: 832 Number of images: 832
# Processing directory 60
# Number of labels: 704 Number of images: 704
# Processing directory 61
# Number of labels: 896 Number of images: 896
# Processing directory 62
# Number of labels: 704 Number of images: 704
# Processing directory 63
# Number of labels: 704 Number of images: 704
# Processing directory 64
# Number of labels: 576 Number of images: 576
# Processing directory 65
# Number of labels: 704 Number of images: 704
# Processing directory 66
# Number of labels: 960 Number of images: 960
# Processing directory 67
# Number of labels: 640 Number of images: 640
# Processing directory 68
# Number of labels: 512 Number of images: 512
# Processing directory 69
# Number of labels: 576 Number of images: 576
# Processing directory 70
# Number of labels: 640 Number of images: 640
# Processing directory 71
# Number of labels: 640 Number of images: 640
# Processing directory 72
# Number of labels: 448 Number of images: 448
# Processing directory 73
# Number of labels: 576 Number of images: 576
# Processing directory 74
# Number of labels: 576 Number of images: 576
# Processing directory 75
# Number of labels: 576 Number of images: 576
# Processing directory 76
# Number of labels: 448 Number of images: 448
# Processing directory 77
# Number of labels: 640 Number of images: 640
# Processing directory 78
# Number of labels: 448 Number of images: 448
# Processing directory 79
# Number of labels: 640 Number of images: 640
# Processing directory 80
# Number of labels: 576 Number of images: 576
# Processing directory 81
# Number of labels: 448 Number of images: 448
# Processing directory 82
# Number of labels: 704 Number of images: 704
# Processing directory 83
# Number of labels: 704 Number of images: 704
# Processing directory 84
# Number of labels: 512 Number of images: 512
# Processing directory 85
# Number of labels: 576 Number of images: 576
# Processing directory 86
# Number of labels: 576 Number of images: 576
# Processing directory 87
# Number of labels: 576 Number of images: 576
# Processing directory 88
# Number of labels: 576 Number of images: 576
# Processing directory 89
# Number of labels: 704 Number of images: 704
# Processing directory 90
# Number of labels: 576 Number of images: 576
# Processing directory 91
# Number of labels: 704 Number of images: 704
# Processing directory 92
# Number of labels: 704 Number of images: 704
# Processing directory 93
# Number of labels: 704 Number of images: 704
# Processing directory 94
# Number of labels: 576 Number of images: 576
# Processing directory 95
# Number of labels: 512 Number of images: 512
# Processing directory 96
# Number of labels: 704 Number of images: 704
# Processing directory 97
# Number of labels: 448 Number of images: 448
# Processing directory 98
# Number of labels: 640 Number of images: 640
# Processing directory 99
# Number of labels: 704 Number of images: 704
# Processing directory 100
# Number of labels: 704 Number of images: 704
# Processing directory 101
# Number of labels: 640 Number of images: 640
# Processing directory 102
# Number of labels: 704 Number of images: 704
# Processing directory 103
# Number of labels: 448 Number of images: 448
# Processing directory 104
# Number of labels: 704 Number of images: 704
# Processing directory 105
# Number of labels: 704 Number of images: 704
# Processing directory 106
# Number of labels: 576 Number of images: 576
# Processing directory 107
# Number of labels: 448 Number of images: 448
# Processing directory 108
# Number of labels: 704 Number of images: 704
# Processing directory 109
# Number of labels: 576 Number of images: 576
# Processing directory 110
# Number of labels: 448 Number of images: 448
# Processing directory 111
# Number of labels: 704 Number of images: 704
# Processing directory 112
# Number of labels: 576 Number of images: 576
# Processing directory 113
# Number of labels: 640 Number of images: 640
# Processing directory 114
# Number of labels: 576 Number of images: 576
# Processing directory 115
# Number of labels: 704 Number of images: 704
# Processing directory 116
# Number of labels: 576 Number of images: 576
# Processing directory 117
# Number of labels: 576 Number of images: 576
# Processing directory 118
# Number of labels: 704 Number of images: 704
# Processing directory 119
# Number of labels: 576 Number of images: 576
# Processing directory 120
# Number of labels: 704 Number of images: 704
# Processing directory 121
# Number of labels: 448 Number of images: 448
# Processing directory 122
# Number of labels: 704 Number of images: 704
# Processing directory 123
# Number of labels: 576 Number of images: 576
# Processing directory 124
# Number of labels: 448 Number of images: 448
# Processing directory 125
# Number of labels: 576 Number of images: 576
# Processing directory 126
# Number of labels: 448 Number of images: 448
# Processing directory 127
# Number of labels: 448 Number of images: 448
# Processing directory 128
# Number of labels: 512 Number of images: 512
# Processing directory 129
# Number of labels: 448 Number of images: 448
# Processing directory 130
# Number of labels: 448 Number of images: 448
# Processing directory 131
# Number of labels: 320 Number of images: 320
# Processing directory 132
# Number of labels: 512 Number of images: 512
# Processing directory 133
# Number of labels: 448 Number of images: 448
# Processing directory 134
# Number of labels: 320 Number of images: 320
# Processing directory 135
# Number of labels: 448 Number of images: 448
# Processing directory 136
# Number of labels: 320 Number of images: 320
# Processing directory 137
# Number of labels: 320 Number of images: 320
# Processing directory 138
# Number of labels: 448 Number of images: 448
# Processing directory 139
# Number of labels: 448 Number of images: 448
# Processing directory 140
# Number of labels: 448 Number of images: 448
# Processing directory 141
# Number of labels: 640 Number of images: 640
# Processing directory 142
# Number of labels: 640 Number of images: 640
# Processing directory 143
# Number of labels: 704 Number of images: 704
# Processing directory 144
# Number of labels: 448 Number of images: 448
# Processing directory 145
# Number of labels: 576 Number of images: 576
# Processing directory 146
# Number of labels: 512 Number of images: 512
# Processing directory 147
# Number of labels: 576 Number of images: 576
# Processing directory 148
# Number of labels: 320 Number of images: 320
# Processing directory 149
# Number of labels: 704 Number of images: 704
# Processing directory 150
# Number of labels: 320 Number of images: 320
# Processing directory 151
# Number of labels: 448 Number of images: 448
# Processing directory 152
# Number of labels: 448 Number of images: 448
# Processing directory 153
# Number of labels: 448 Number of images: 448
# Processing directory 154
# Number of labels: 512 Number of images: 512
# Processing directory 155
# Number of labels: 704 Number of images: 704
# Processing directory 156
# Number of labels: 704 Number of images: 704
# Processing directory 157
# Number of labels: 704 Number of images: 704
# Processing directory 158
# Number of labels: 640 Number of images: 640
# Processing directory 159
# Number of labels: 448 Number of images: 448
# Processing directory 160
# Number of labels: 704 Number of images: 704
# Processing directory 161
# Number of labels: 704 Number of images: 704
# Processing directory 162
# Number of labels: 576 Number of images: 576
# Processing directory 163
# Number of labels: 512 Number of images: 512
# Processing directory 164
# Number of labels: 704 Number of images: 704
# Processing directory 165
# Number of labels: 448 Number of images: 448
# Processing directory 166
# Number of labels: 576 Number of images: 576
# Processing directory 167
# Number of labels: 704 Number of images: 704
# Processing directory 168
# Number of labels: 448 Number of images: 448
# Processing directory 169
# Number of labels: 576 Number of images: 576
# Processing directory 170
# Number of labels: 448 Number of images: 448
# Processing directory 171
# Number of labels: 320 Number of images: 320
# Processing directory 172
# Number of labels: 448 Number of images: 448
# Processing directory 173
# Number of labels: 640 Number of images: 640
# Processing directory 174
# Number of labels: 576 Number of images: 576
# Processing directory 175
# Number of labels: 512 Number of images: 512
# Processing directory 176
# Number of labels: 576 Number of images: 576
# Processing directory 177
# Number of labels: 512 Number of images: 512
# Processing directory 178
# Number of labels: 512 Number of images: 512
# Processing directory 179
# Number of labels: 640 Number of images: 640
# Processing directory 180
# Number of labels: 704 Number of images: 704
# Processing directory 181
# Number of labels: 320 Number of images: 320
# Processing directory 182
# Number of labels: 448 Number of images: 448
# Processing directory 183
# Number of labels: 704 Number of images: 704
# Processing directory 184
# Number of labels: 448 Number of images: 448
# Processing directory 185
# Number of labels: 512 Number of images: 512
# Processing directory 186
# Number of labels: 320 Number of images: 320
# Processing directory 187
# Number of labels: 448 Number of images: 448
# Processing directory 188
# Number of labels: 704 Number of images: 704
# Processing directory 189
# Number of labels: 512 Number of images: 512
# Processing directory 190
# Number of labels: 704 Number of images: 704
# Processing directory 191
# Number of labels: 704 Number of images: 704
# Processing directory 192
# Number of labels: 448 Number of images: 448
# Processing directory 193
# Number of labels: 448 Number of images: 448
# Processing directory 194
# Number of labels: 320 Number of images: 320
# Processing directory 195
# Number of labels: 448 Number of images: 448
# Processing directory 196
# Number of labels: 448 Number of images: 448
# Processing directory 197
# Number of labels: 640 Number of images: 640
# Processing directory 198
# Number of labels: 576 Number of images: 576
# Processing directory 199
# Number of labels: 448 Number of images: 448
# Processing directory 200
# Number of labels: 448 Number of images: 448
# Processing directory 201
# Number of labels: 704 Number of images: 704
# Processing directory 202
# Number of labels: 576 Number of images: 576
# Processing directory 203
# Number of labels: 704 Number of images: 704
# Processing directory 204
# Number of labels: 512 Number of images: 512
# Processing directory 205
# Number of labels: 576 Number of images: 576
# Processing directory 206
# Number of labels: 704 Number of images: 704
# Processing directory 207
# Number of labels: 576 Number of images: 576
# Processing directory 208
# Number of labels: 640 Number of images: 640
# Processing directory 209
# Number of labels: 576 Number of images: 576
# Processing directory 210
# Number of labels: 576 Number of images: 576
# Processing directory 211
# Number of labels: 448 Number of images: 448
# Processing directory 212
# Number of labels: 576 Number of images: 576
# Processing directory 213
# Number of labels: 576 Number of images: 576
# Processing directory 214
# Number of labels: 640 Number of images: 640
# Processing directory 215
# Number of labels: 576 Number of images: 576
# Processing directory 216
# Number of labels: 704 Number of images: 704
# Processing directory 217
# Number of labels: 320 Number of images: 320
# Processing directory 218
# Number of labels: 448 Number of images: 448
# Processing directory 219
# Number of labels: 640 Number of images: 640
# Processing directory 220
# Number of labels: 448 Number of images: 448
# Processing directory 221
# Number of labels: 576 Number of images: 576
# Processing directory 222
# Number of labels: 448 Number of images: 448
# Processing directory 223
# Number of labels: 704 Number of images: 704
# Processing directory 224
# Number of labels: 320 Number of images: 320
# Processing directory 225
# Number of labels: 704 Number of images: 704
# Processing directory 226
# Number of labels: 576 Number of images: 576
# Processing directory 227
# Number of labels: 704 Number of images: 704
# Processing directory 228
# Number of labels: 576 Number of images: 576
# Processing directory 229
# Number of labels: 512 Number of images: 512
# Processing directory 230
# Number of labels: 448 Number of images: 448
# Processing directory 231
# Number of labels: 512 Number of images: 512
# Processing directory 232
# Number of labels: 704 Number of images: 704
# Processing directory 233
# Number of labels: 576 Number of images: 576
# Processing directory 234
# Number of labels: 576 Number of images: 576
# Processing directory 235
# Number of labels: 704 Number of images: 704
# Processing directory 236
# Number of labels: 576 Number of images: 576
# Processing directory 237
# Number of labels: 704 Number of images: 704
# Processing directory 238
# Number of labels: 576 Number of images: 576
# Processing directory 239
# Number of labels: 576 Number of images: 576
# Processing directory 240
# Number of labels: 704 Number of images: 704
# Processing directory 241
# Number of labels: 704 Number of images: 704
# Processing directory 242
# Number of labels: 576 Number of images: 576
# Processing directory 243
# Number of labels: 576 Number of images: 576
# Processing directory 244
# Number of labels: 640 Number of images: 640
# Processing directory 245
# Number of labels: 512 Number of images: 512
# Processing directory 246
# Number of labels: 320 Number of images: 320
# Processing directory 247
# Number of labels: 704 Number of images: 704
# Processing directory 248
# Number of labels: 704 Number of images: 704
# Processing directory 249
# Number of labels: 576 Number of images: 576
# Processing directory 250
# Number of labels: 704 Number of images: 704
# Processing directory 251
# Number of labels: 448 Number of images: 448
# Processing directory 252
# Number of labels: 640 Number of images: 640
# Processing directory 253
# Number of labels: 640 Number of images: 640
# Processing directory 254
# Number of labels: 576 Number of images: 576
# Processing directory 255
# Number of labels: 320 Number of images: 320
# Processing directory 256
# Number of labels: 448 Number of images: 448
# Processing directory 257
# Number of labels: 576 Number of images: 576
# Processing directory 258
# Number of labels: 448 Number of images: 448
# Processing directory 259
# Number of labels: 448 Number of images: 448
# Processing directory 260
# Number of labels: 704 Number of images: 704
# Processing directory 261
# Number of labels: 576 Number of images: 576
# Processing directory 262
# Number of labels: 704 Number of images: 704
# Processing directory 263
# Number of labels: 704 Number of images: 704
# Processing directory 264
# Number of labels: 576 Number of images: 576
# Processing directory 265
# Number of labels: 448 Number of images: 448
# Processing directory 266
# Number of labels: 704 Number of images: 704
# Processing directory 267
# Number of labels: 640 Number of images: 640
# Processing directory 268
# Number of labels: 448 Number of images: 448
# Processing directory 269
# Number of labels: 448 Number of images: 448
# Processing directory 270
# Number of labels: 576 Number of images: 576
# Processing directory 271
# Number of labels: 576 Number of images: 576
# Processing directory 272
# Number of labels: 640 Number of images: 640
# Processing directory 273
# Number of labels: 448 Number of images: 448
# Processing directory 274
# Number of labels: 448 Number of images: 448
# Processing directory 275
# Number of labels: 448 Number of images: 448
# Processing directory 276
# Number of labels: 704 Number of images: 704
# Processing directory 277
# Number of labels: 448 Number of images: 448
# Processing directory 278
# Number of labels: 448 Number of images: 448
# Processing directory 279
# Number of labels: 576 Number of images: 576
# Processing directory 280
# Number of labels: 704 Number of images: 704
# Processing directory 281
# Number of labels: 320 Number of images: 320
# Processing directory 282
# Number of labels: 448 Number of images: 448
# Processing directory 283
# Number of labels: 64 Number of images: 64
# Processing directory 284
# Number of labels: 64 Number of images: 64
# Processing directory 285
# Number of labels: 64 Number of images: 64
# Processing directory 286
# Number of labels: 64 Number of images: 64
# Processing directory 287
# Number of labels: 64 Number of images: 64
# Processing directory 288
# Number of labels: 64 Number of images: 64
# Processing directory 289
# Number of labels: 64 Number of images: 64
# Processing directory 290
# Number of labels: 64 Number of images: 64
# Processing directory 291
# Number of labels: 64 Number of images: 64
# Processing directory 292
# Number of labels: 64 Number of images: 64
# Processing directory 293
# Number of labels: 64 Number of images: 64
# Processing directory 294
# Number of labels: 64 Number of images: 64
# Processing directory 295
# Number of labels: 64 Number of images: 64
# Processing directory 296
# Number of labels: 64 Number of images: 64
# Processing directory 297
# Number of labels: 64 Number of images: 64
# Processing directory 298
# Number of labels: 64 Number of images: 64
# Processing directory 299
# Number of labels: 64 Number of images: 64
# Processing directory 300
# Number of labels: 64 Number of images: 64
# Processing directory 301
# Number of labels: 64 Number of images: 64
# Processing directory 302
# Number of labels: 64 Number of images: 64
# Processing directory 303
# Number of labels: 64 Number of images: 64
# Processing directory 304
# Number of labels: 64 Number of images: 64
# Processing directory 305
# Number of labels: 64 Number of images: 64
# Processing directory 306
# Number of labels: 64 Number of images: 64
# Processing directory 307
# Number of labels: 64 Number of images: 64
# Processing directory 308
# Number of labels: 64 Number of images: 64
# Processing directory 309
# Number of labels: 64 Number of images: 64
# Processing directory 310
# Number of labels: 64 Number of images: 64
# Processing directory 311
# Number of labels: 64 Number of images: 64
# Processing directory 312
# Number of labels: 64 Number of images: 64
# Processing directory 313
# Number of labels: 64 Number of images: 64
# Processing directory 314
# Number of labels: 64 Number of images: 64
# Processing directory 315
# Number of labels: 64 Number of images: 64
# Processing directory 316
# Number of labels: 64 Number of images: 64
# Processing directory 317
# Number of labels: 64 Number of images: 64
# Processing directory 318
# Number of labels: 64 Number of images: 64
# Processing directory 319
# Number of labels: 64 Number of images: 64
# Processing directory 320
# Number of labels: 64 Number of images: 64
# Processing directory 321
# Number of labels: 64 Number of images: 64
# Processing directory 322
# Number of labels: 64 Number of images: 64
# Processing directory 323
# Number of labels: 64 Number of images: 64
# Processing directory 324
# Number of labels: 64 Number of images: 64
# Processing directory 325
# Number of labels: 64 Number of images: 64
# Processing directory 326
# Number of labels: 64 Number of images: 64
# Processing directory 327
# Number of labels: 64 Number of images: 64
# Processing directory 328
# Number of labels: 64 Number of images: 64
# Processing directory 329
# Number of labels: 64 Number of images: 64
# Processing directory 330
# Number of labels: 64 Number of images: 64
# Processing directory 331
# Number of labels: 64 Number of images: 64
# Processing directory 332
# Number of labels: 64 Number of images: 64
# Processing directory 333
# Number of labels: 64 Number of images: 64
# Processing directory 334
# Number of labels: 64 Number of images: 64
# Processing directory 335
# Number of labels: 64 Number of images: 64
# Processing directory 336
# Number of labels: 64 Number of images: 64
# Processing directory 337
# Number of labels: 64 Number of images: 64
# Processing directory 338
# Number of labels: 64 Number of images: 64
# Processing directory 339
# Number of labels: 64 Number of images: 64
# Processing directory 340
# Number of labels: 64 Number of images: 64
# Processing directory 341
# Number of labels: 64 Number of images: 64
# Processing directory 342
# Number of labels: 64 Number of images: 64
# Processing directory 343
# Number of labels: 64 Number of images: 64
# Processing directory 344
# Number of labels: 64 Number of images: 64
# Processing directory 345
# Number of labels: 64 Number of images: 64
# Processing directory 346
# Number of labels: 64 Number of images: 64
# Processing directory 347
# Number of labels: 64 Number of images: 64
# Processing directory 348
# Number of labels: 64 Number of images: 64
# Processing directory 349
# Number of labels: 64 Number of images: 64
# Processing directory 350
# Number of labels: 64 Number of images: 64
# Processing directory 351
# Number of labels: 64 Number of images: 64
# Processing directory 352
# Number of labels: 64 Number of images: 64
# Processing directory 353
# Number of labels: 64 Number of images: 64
# Processing directory 354
# Number of labels: 64 Number of images: 64
# Processing directory 355
# Number of labels: 64 Number of images: 64
# Processing directory 356
# Number of labels: 64 Number of images: 64
# Processing directory 357
# Number of labels: 64 Number of images: 64
# Processing directory 358
# Number of labels: 64 Number of images: 64
# Processing directory 359
# Number of labels: 64 Number of images: 64
# Processing directory 360
# Number of labels: 64 Number of images: 64
# Processing directory 361
# Number of labels: 64 Number of images: 64
# Processing directory 362
# Number of labels: 64 Number of images: 64
# Processing directory 363
# Number of labels: 64 Number of images: 64
# Processing directory 364
# Number of labels: 64 Number of images: 64
# Processing directory 365
# Number of labels: 64 Number of images: 64
# Processing directory 366
# Number of labels: 64 Number of images: 64
# Processing directory 367
# Number of labels: 64 Number of images: 64
# Processing directory 368
# Number of labels: 64 Number of images: 64
# Processing directory 369
# Number of labels: 64 Number of images: 64
# Processing directory 370
# Number of labels: 64 Number of images: 64
# Processing directory 371
# Number of labels: 64 Number of images: 64
# Processing directory 372
# Number of labels: 64 Number of images: 64
# Processing directory 373
# Number of labels: 64 Number of images: 64
# Processing directory 374
# Number of labels: 64 Number of images: 64
# Processing directory 375
# Number of labels: 64 Number of images: 64
# Processing directory 376
# Number of labels: 64 Number of images: 64
# Processing directory 377
# Number of labels: 64 Number of images: 64
# Processing directory 378
# Number of labels: 64 Number of images: 64
# Processing directory 379
# Number of labels: 64 Number of images: 64
# Processing directory 380
# Number of labels: 64 Number of images: 64
# Processing directory 381
# Number of labels: 64 Number of images: 64
# Processing directory 382
# Number of labels: 64 Number of images: 64
# Processing directory 383
# Number of labels: 64 Number of images: 64
# Processing directory 384
# Number of labels: 64 Number of images: 64
# Processing directory 385
# Number of labels: 64 Number of images: 64
# Processing directory 386
# Number of labels: 64 Number of images: 64
# Processing directory 387
# Number of labels: 64 Number of images: 64
# Processing directory 388
# Number of labels: 64 Number of images: 64
# Processing directory 389
# Number of labels: 64 Number of images: 64
# Processing directory 390
# Number of labels: 64 Number of images: 64
# Processing directory 391
# Number of labels: 64 Number of images: 64
# Processing directory 392
# Number of labels: 64 Number of images: 64
# Processing directory 393
# Number of labels: 64 Number of images: 64
# Processing directory 394
# Number of labels: 64 Number of images: 64
# Processing directory 395
# Number of labels: 64 Number of images: 64
# Processing directory 396
# Number of labels: 64 Number of images: 64
# Processing directory 397
# Number of labels: 64 Number of images: 64
# Processing directory 398
# Number of labels: 64 Number of images: 64
# Processing directory 399
# Number of labels: 64 Number of images: 64
# Processing directory 400
# Number of labels: 64 Number of images: 64
# Processing directory 401
# Number of labels: 64 Number of images: 64
# Processing directory 402
# Number of labels: 64 Number of images: 64
# Processing directory 403
# Number of labels: 64 Number of images: 64
# Processing directory 404
# Number of labels: 64 Number of images: 64
# Processing directory 405
# Number of labels: 64 Number of images: 64
# Processing directory 406
# Number of labels: 64 Number of images: 64
# Processing directory 407
# Number of labels: 64 Number of images: 64
# Processing directory 408
# Number of labels: 64 Number of images: 64
# Processing directory 409
# Number of labels: 64 Number of images: 64
# Processing directory 410
# Number of labels: 64 Number of images: 64
# Processing directory 411
# Number of labels: 64 Number of images: 64
# Processing directory 412
# Number of labels: 64 Number of images: 64
# Processing directory 413
# Processing directory 414
# Number of labels: 64 Number of images: 64
# Processing directory 415
# Number of labels: 64 Number of images: 64
# Processing directory 416
# Number of labels: 52 Number of images: 52
# Processing directory 417
# Number of labels: 64 Number of images: 64
# Processing directory 418
# Number of labels: 52 Number of images: 52
# Processing directory 419
# Number of labels: 52 Number of images: 52
# Processing directory 420
# Number of labels: 64 Number of images: 64
# Processing directory 421
# Number of labels: 64 Number of images: 64
# Processing directory 422
# Number of labels: 64 Number of images: 64
# Processing directory 423
# Number of labels: 64 Number of images: 64
# Processing directory 424
# Number of labels: 64 Number of images: 64
# Processing directory 425
# Number of labels: 64 Number of images: 64
# Processing directory 426
# Number of labels: 64 Number of images: 64
# Processing directory 427
# Number of labels: 64 Number of images: 64
# Processing directory 428
# Number of labels: 64 Number of images: 64
# Processing directory 429
# Number of labels: 64 Number of images: 64
# Processing directory 430
# Number of labels: 52 Number of images: 52
# Processing directory 431
# Number of labels: 64 Number of images: 64
# Processing directory 432
# Number of labels: 52 Number of images: 52
# Processing directory 433
# Number of labels: 64 Number of images: 64
# Processing directory 434
# Number of labels: 64 Number of images: 64
# Processing directory 435
# Number of labels: 64 Number of images: 64
# Processing directory 436
# Number of labels: 64 Number of images: 64
# Processing directory 437
# Number of labels: 64 Number of images: 64
# Processing directory 438
# Number of labels: 64 Number of images: 64
# Processing directory 439
# Number of labels: 64 Number of images: 64
# Processing directory 440
# Number of labels: 64 Number of images: 64
# Processing directory 441
# Number of labels: 64 Number of images: 64
# Processing directory 442
# Number of labels: 64 Number of images: 64
# Processing directory 443
# Number of labels: 64 Number of images: 64
# Processing directory 444
# Number of labels: 64 Number of images: 64
# Processing directory 445
# Number of labels: 64 Number of images: 64
# Processing directory 446
# Number of labels: 64 Number of images: 64
# Processing directory 447
# Number of labels: 64 Number of images: 64
# Processing directory 448
# Number of labels: 64 Number of images: 64
# Processing directory 449
# Number of labels: 64 Number of images: 64
# Processing directory 450
# Number of labels: 64 Number of images: 64
# Processing directory 451
# Number of labels: 64 Number of images: 64
# Processing directory 452
# Number of labels: 64 Number of images: 64
# Processing directory 453
# Number of labels: 52 Number of images: 52
# Processing directory 454
# Number of labels: 64 Number of images: 64
# Processing directory 455
# Number of labels: 64 Number of images: 64
# Processing directory 456
# Number of labels: 64 Number of images: 64
# Processing directory 457
# Number of labels: 64 Number of images: 64
# Processing directory 458
# Number of labels: 64 Number of images: 64
# Processing directory 459
# Number of labels: 64 Number of images: 64
# Processing directory 460
# Number of labels: 64 Number of images: 64
# Processing directory 461
# Number of labels: 64 Number of images: 64
# Processing directory 462
# Number of labels: 64 Number of images: 64
# Processing directory 463
# Number of labels: 52 Number of images: 52
# Processing directory 464
# Number of labels: 64 Number of images: 64
# Processing directory 465
# Number of labels: 64 Number of images: 64
# Processing directory 466
# Number of labels: 64 Number of images: 64
# Processing directory 467
# Number of labels: 64 Number of images: 64
# Processing directory 468
# Number of labels: 52 Number of images: 52
# Processing directory 469
# Number of labels: 64 Number of images: 64
# Processing directory 470
# Number of labels: 64 Number of images: 64
# Processing directory 471
# Number of labels: 64 Number of images: 64
# Processing directory 472
# Number of labels: 64 Number of images: 64
# Processing directory 473
# Number of labels: 64 Number of images: 64
# Processing directory 474
# Number of labels: 64 Number of images: 64
# Processing directory 475
# Number of labels: 64 Number of images: 64
# Processing directory 476
# Number of labels: 52 Number of images: 52
# Processing directory 477
# Number of labels: 64 Number of images: 64
# Processing directory 478
# Number of labels: 64 Number of images: 64
# Processing directory 479
# Number of labels: 64 Number of images: 64
# Processing directory 480
# Number of labels: 64 Number of images: 64
# Processing directory 481
# Number of labels: 64 Number of images: 64
# Processing directory 482
# Number of labels: 64 Number of images: 64
# Processing directory 483
# Number of labels: 64 Number of images: 64
# Processing directory 484
# Number of labels: 64 Number of images: 64
# Processing directory 485
# Number of labels: 64 Number of images: 64
# Processing directory 486
# Number of labels: 64 Number of images: 64
# Processing directory 487
# Number of labels: 64 Number of images: 64
# Processing directory 488
# Number of labels: 64 Number of images: 64
# Processing directory 489
# Number of labels: 64 Number of images: 64
# Processing directory 490
# Number of labels: 64 Number of images: 64
# Processing directory 491
# Number of labels: 64 Number of images: 64
# Processing directory 492
# Number of labels: 64 Number of images: 64
# Processing directory 493
# Number of labels: 64 Number of images: 64
# Processing directory 494
# Number of labels: 64 Number of images: 64
# Processing directory 495
# Number of labels: 64 Number of images: 64
# Processing directory 496
# Number of labels: 64 Number of images: 64
# Processing directory 497
# Number of labels: 64 Number of images: 64
# Processing directory 498
# Number of labels: 64 Number of images: 64
# Processing directory 499
# Number of labels: 52 Number of images: 52
# Processing directory 500
# Number of labels: 64 Number of images: 64
# Processing directory 501
# Number of labels: 64 Number of images: 64
# Processing directory 502
# Number of labels: 64 Number of images: 64
# Processing directory 503
# Number of labels: 64 Number of images: 64
# Processing directory 504
# Number of labels: 64 Number of images: 64
# Processing directory 505
# Number of labels: 64 Number of images: 64
# Processing directory 506
# Number of labels: 52 Number of images: 52
# Processing directory 507
# Number of labels: 64 Number of images: 64
# Processing directory 508
# Number of labels: 64 Number of images: 64
# Processing directory 509
# Number of labels: 64 Number of images: 64
# Processing directory 510
# Number of labels: 64 Number of images: 64
# Processing directory 511
# Number of labels: 64 Number of images: 64
# Processing directory 512
# Number of labels: 64 Number of images: 64
# Processing directory 513
# Number of labels: 64 Number of images: 64
# Processing directory 514
# Number of labels: 64 Number of images: 64
# Processing directory 515
# Number of labels: 64 Number of images: 64
# Processing directory 516
# Number of labels: 64 Number of images: 64
# Processing directory 517
# Number of labels: 64 Number of images: 64
# Processing directory 518
# Number of labels: 64 Number of images: 64
# Processing directory 519
# Number of labels: 64 Number of images: 64
# Processing directory 520
# Number of labels: 64 Number of images: 64
# Processing directory 521
# Number of labels: 64 Number of images: 64
# Processing directory 522
# Number of labels: 64 Number of images: 64
# Processing directory 523
# Number of labels: 64 Number of images: 64
# Processing directory 524
# Number of labels: 64 Number of images: 64
# Processing directory 525
# Number of labels: 64 Number of images: 64
# Processing directory 526
# Number of labels: 64 Number of images: 64
# Processing directory 527
# Number of labels: 64 Number of images: 64
# Processing directory 528
# Number of labels: 52 Number of images: 52
# Processing directory 529
# Number of labels: 64 Number of images: 64
# Processing directory 530
# Number of labels: 64 Number of images: 64
# Processing directory 531
# Number of labels: 64 Number of images: 64
# Processing directory 532
# Number of labels: 64 Number of images: 64
# Processing directory 533
# Number of labels: 64 Number of images: 64
# Processing directory 534
# Number of labels: 64 Number of images: 64
# Processing directory 535
# Number of labels: 64 Number of images: 64
# Processing directory 536
# Number of labels: 64 Number of images: 64
# Processing directory 537
# Number of labels: 52 Number of images: 52
# Processing directory 538
# Number of labels: 64 Number of images: 64
# Processing directory 539
# Number of labels: 64 Number of images: 64
# Processing directory 540
# Number of labels: 64 Number of images: 64
# Processing directory 541
# Number of labels: 64 Number of images: 64
# Processing directory 542
# Number of labels: 64 Number of images: 64
# Processing directory 543
# Number of labels: 64 Number of images: 64
# Processing directory 544
# Number of labels: 64 Number of images: 64
# Processing directory 545
# Number of labels: 64 Number of images: 64
# Processing directory 546
# Number of labels: 64 Number of images: 64
# Processing directory 547
# Number of labels: 64 Number of images: 64
# Processing directory 548
# Number of labels: 64 Number of images: 64
# Processing directory 549
# Number of labels: 64 Number of images: 64
# Processing directory 550
# Number of labels: 64 Number of images: 64
# Processing directory 551
# Number of labels: 64 Number of images: 64
# Processing directory 552
# Number of labels: 64 Number of images: 64
# Processing directory 553
# Number of labels: 64 Number of images: 64
# Processing directory 554
# Number of labels: 64 Number of images: 64
# Processing directory 555
# Number of labels: 64 Number of images: 64
# Processing directory 556
# Number of labels: 64 Number of images: 64
# Processing directory 557
# Number of labels: 64 Number of images: 64
# Processing directory 558
# Number of labels: 64 Number of images: 64
# Processing directory 559
# Number of labels: 64 Number of images: 64
# Processing directory 560
# Number of labels: 64 Number of images: 64
# Processing directory 561
# Number of labels: 64 Number of images: 64
# Processing directory 562
# Number of labels: 64 Number of images: 64

# %%
import os

def rename_files_and_folders(folder_path, start_number=1):
    """
    Renames all files and folders in the specified folder with a given prefix and sequential numbers.

    :param folder_path: Path to the folder containing the files and folders to rename.
    :param prefix: Prefix to use for the renamed items.
    :param start_number: Starting number for the sequential naming.
    """
    try:
        items = sorted([int(i) for i in os.listdir(folder_path)])
        for count, item_name in enumerate(items, start=start_number):
            old_item_path = os.path.join(folder_path, str(item_name))
            
            if os.path.isdir(old_item_path):
                new_item_name = f'{count}'
            else:
                # Skip non-file/folder items
                continue
            
            new_item_path = os.path.join(folder_path, new_item_name)
            
            # Rename the item
            os.rename(old_item_path, new_item_path)
            print(f"Renamed: {item_name} -> {new_item_name}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Usage Example
folder_path = "quadrant_dataset"
rename_files_and_folders(folder_path)
# Out:
# Renamed: 1 -> 1
# Renamed: 2 -> 2
# Renamed: 3 -> 3
# Renamed: 4 -> 4
# Renamed: 5 -> 5
# Renamed: 6 -> 6
# Renamed: 7 -> 7
# Renamed: 8 -> 8
# Renamed: 9 -> 9
# Renamed: 10 -> 10
# Renamed: 11 -> 11
# Renamed: 12 -> 12
# Renamed: 13 -> 13
# Renamed: 14 -> 14
# Renamed: 15 -> 15
# Renamed: 16 -> 16
# Renamed: 17 -> 17
# Renamed: 18 -> 18
# Renamed: 19 -> 19
# Renamed: 20 -> 20
# Renamed: 21 -> 21
# Renamed: 22 -> 22
# Renamed: 23 -> 23
# Renamed: 24 -> 24
# Renamed: 25 -> 25
# Renamed: 26 -> 26
# Renamed: 27 -> 27
# Renamed: 28 -> 28
# Renamed: 29 -> 29
# Renamed: 30 -> 30
# Renamed: 31 -> 31
# Renamed: 32 -> 32
# Renamed: 33 -> 33
# Renamed: 34 -> 34
# Renamed: 35 -> 35
# Renamed: 36 -> 36
# Renamed: 37 -> 37
# Renamed: 38 -> 38
# Renamed: 39 -> 39
# Renamed: 40 -> 40
# Renamed: 41 -> 41
# Renamed: 42 -> 42
# Renamed: 43 -> 43
# Renamed: 44 -> 44
# Renamed: 45 -> 45
# Renamed: 46 -> 46
# Renamed: 47 -> 47
# Renamed: 48 -> 48
# Renamed: 49 -> 49
# Renamed: 50 -> 50
# Renamed: 51 -> 51
# Renamed: 52 -> 52
# Renamed: 53 -> 53
# Renamed: 54 -> 54
# Renamed: 55 -> 55
# Renamed: 56 -> 56
# Renamed: 57 -> 57
# Renamed: 58 -> 58
# Renamed: 59 -> 59
# Renamed: 60 -> 60
# Renamed: 61 -> 61
# Renamed: 62 -> 62
# Renamed: 63 -> 63
# Renamed: 64 -> 64
# Renamed: 65 -> 65
# Renamed: 66 -> 66
# Renamed: 67 -> 67
# Renamed: 68 -> 68
# Renamed: 69 -> 69
# Renamed: 70 -> 70
# Renamed: 71 -> 71
# Renamed: 72 -> 72
# Renamed: 73 -> 73
# Renamed: 74 -> 74
# Renamed: 75 -> 75
# Renamed: 76 -> 76
# Renamed: 77 -> 77
# Renamed: 78 -> 78
# Renamed: 79 -> 79
# Renamed: 80 -> 80
# Renamed: 81 -> 81
# Renamed: 82 -> 82
# Renamed: 83 -> 83
# Renamed: 84 -> 84
# Renamed: 85 -> 85
# Renamed: 86 -> 86
# Renamed: 87 -> 87
# Renamed: 88 -> 88
# Renamed: 89 -> 89
# Renamed: 90 -> 90
# Renamed: 91 -> 91
# Renamed: 92 -> 92
# Renamed: 93 -> 93
# Renamed: 94 -> 94
# Renamed: 95 -> 95
# Renamed: 96 -> 96
# Renamed: 97 -> 97
# Renamed: 98 -> 98
# Renamed: 99 -> 99
# Renamed: 100 -> 100
# Renamed: 101 -> 101
# Renamed: 102 -> 102
# Renamed: 103 -> 103
# Renamed: 104 -> 104
# Renamed: 105 -> 105
# Renamed: 106 -> 106
# Renamed: 107 -> 107
# Renamed: 108 -> 108
# Renamed: 109 -> 109
# Renamed: 110 -> 110
# Renamed: 111 -> 111
# Renamed: 112 -> 112
# Renamed: 113 -> 113
# Renamed: 114 -> 114
# Renamed: 115 -> 115
# Renamed: 116 -> 116
# Renamed: 117 -> 117
# Renamed: 118 -> 118
# Renamed: 119 -> 119
# Renamed: 120 -> 120
# Renamed: 121 -> 121
# Renamed: 122 -> 122
# Renamed: 123 -> 123
# Renamed: 124 -> 124
# Renamed: 125 -> 125
# Renamed: 126 -> 126
# Renamed: 127 -> 127
# Renamed: 128 -> 128
# Renamed: 129 -> 129
# Renamed: 130 -> 130
# Renamed: 131 -> 131
# Renamed: 132 -> 132
# Renamed: 133 -> 133
# Renamed: 134 -> 134
# Renamed: 135 -> 135
# Renamed: 136 -> 136
# Renamed: 137 -> 137
# Renamed: 138 -> 138
# Renamed: 139 -> 139
# Renamed: 140 -> 140
# Renamed: 141 -> 141
# Renamed: 142 -> 142
# Renamed: 143 -> 143
# Renamed: 144 -> 144
# Renamed: 145 -> 145
# Renamed: 146 -> 146
# Renamed: 147 -> 147
# Renamed: 148 -> 148
# Renamed: 149 -> 149
# Renamed: 150 -> 150
# Renamed: 151 -> 151
# Renamed: 152 -> 152
# Renamed: 153 -> 153
# Renamed: 154 -> 154
# Renamed: 155 -> 155
# Renamed: 156 -> 156
# Renamed: 157 -> 157
# Renamed: 158 -> 158
# Renamed: 159 -> 159
# Renamed: 160 -> 160
# Renamed: 161 -> 161
# Renamed: 162 -> 162
# Renamed: 163 -> 163
# Renamed: 164 -> 164
# Renamed: 165 -> 165
# Renamed: 166 -> 166
# Renamed: 167 -> 167
# Renamed: 168 -> 168
# Renamed: 169 -> 169
# Renamed: 170 -> 170
# Renamed: 171 -> 171
# Renamed: 172 -> 172
# Renamed: 173 -> 173
# Renamed: 174 -> 174
# Renamed: 175 -> 175
# Renamed: 176 -> 176
# Renamed: 177 -> 177
# Renamed: 178 -> 178
# Renamed: 179 -> 179
# Renamed: 180 -> 180
# Renamed: 181 -> 181
# Renamed: 182 -> 182
# Renamed: 183 -> 183
# Renamed: 184 -> 184
# Renamed: 185 -> 185
# Renamed: 186 -> 186
# Renamed: 187 -> 187
# Renamed: 188 -> 188
# Renamed: 189 -> 189
# Renamed: 190 -> 190
# Renamed: 191 -> 191
# Renamed: 192 -> 192
# Renamed: 193 -> 193
# Renamed: 194 -> 194
# Renamed: 195 -> 195
# Renamed: 196 -> 196
# Renamed: 197 -> 197
# Renamed: 198 -> 198
# Renamed: 199 -> 199
# Renamed: 200 -> 200
# Renamed: 201 -> 201
# Renamed: 202 -> 202
# Renamed: 203 -> 203
# Renamed: 204 -> 204
# Renamed: 205 -> 205
# Renamed: 206 -> 206
# Renamed: 207 -> 207
# Renamed: 208 -> 208
# Renamed: 209 -> 209
# Renamed: 210 -> 210
# Renamed: 211 -> 211
# Renamed: 212 -> 212
# Renamed: 213 -> 213
# Renamed: 214 -> 214
# Renamed: 215 -> 215
# Renamed: 216 -> 216
# Renamed: 217 -> 217
# Renamed: 218 -> 218
# Renamed: 219 -> 219
# Renamed: 220 -> 220
# Renamed: 221 -> 221
# Renamed: 222 -> 222
# Renamed: 223 -> 223
# Renamed: 224 -> 224
# Renamed: 225 -> 225
# Renamed: 226 -> 226
# Renamed: 227 -> 227
# Renamed: 228 -> 228
# Renamed: 229 -> 229
# Renamed: 230 -> 230
# Renamed: 231 -> 231
# Renamed: 232 -> 232
# Renamed: 233 -> 233
# Renamed: 234 -> 234
# Renamed: 235 -> 235
# Renamed: 236 -> 236
# Renamed: 237 -> 237
# Renamed: 238 -> 238
# Renamed: 239 -> 239
# Renamed: 240 -> 240
# Renamed: 241 -> 241
# Renamed: 242 -> 242
# Renamed: 243 -> 243
# Renamed: 244 -> 244
# Renamed: 245 -> 245
# Renamed: 246 -> 246
# Renamed: 247 -> 247
# Renamed: 248 -> 248
# Renamed: 249 -> 249
# Renamed: 250 -> 250
# Renamed: 251 -> 251
# Renamed: 252 -> 252
# Renamed: 253 -> 253
# Renamed: 254 -> 254
# Renamed: 255 -> 255
# Renamed: 256 -> 256
# Renamed: 257 -> 257
# Renamed: 258 -> 258
# Renamed: 259 -> 259
# Renamed: 260 -> 260
# Renamed: 261 -> 261
# Renamed: 262 -> 262
# Renamed: 263 -> 263
# Renamed: 264 -> 264
# Renamed: 265 -> 265
# Renamed: 266 -> 266
# Renamed: 267 -> 267
# Renamed: 268 -> 268
# Renamed: 269 -> 269
# Renamed: 270 -> 270
# Renamed: 271 -> 271
# Renamed: 272 -> 272
# Renamed: 273 -> 273
# Renamed: 274 -> 274
# Renamed: 275 -> 275
# Renamed: 276 -> 276
# Renamed: 277 -> 277
# Renamed: 278 -> 278
# Renamed: 279 -> 279
# Renamed: 280 -> 280
# Renamed: 281 -> 281
# Renamed: 282 -> 282
# Renamed: 283 -> 283
# Renamed: 284 -> 284
# Renamed: 285 -> 285
# Renamed: 286 -> 286
# Renamed: 287 -> 287
# Renamed: 288 -> 288
# Renamed: 289 -> 289
# Renamed: 290 -> 290
# Renamed: 291 -> 291
# Renamed: 292 -> 292
# Renamed: 293 -> 293
# Renamed: 294 -> 294
# Renamed: 295 -> 295
# Renamed: 296 -> 296
# Renamed: 297 -> 297
# Renamed: 298 -> 298
# Renamed: 299 -> 299
# Renamed: 300 -> 300
# Renamed: 301 -> 301
# Renamed: 302 -> 302
# Renamed: 303 -> 303
# Renamed: 304 -> 304
# Renamed: 305 -> 305
# Renamed: 306 -> 306
# Renamed: 307 -> 307
# Renamed: 308 -> 308
# Renamed: 309 -> 309
# Renamed: 310 -> 310
# Renamed: 311 -> 311
# Renamed: 312 -> 312
# Renamed: 313 -> 313
# Renamed: 314 -> 314
# Renamed: 315 -> 315
# Renamed: 316 -> 316
# Renamed: 317 -> 317
# Renamed: 318 -> 318
# Renamed: 319 -> 319
# Renamed: 320 -> 320
# Renamed: 321 -> 321
# Renamed: 322 -> 322
# Renamed: 323 -> 323
# Renamed: 324 -> 324
# Renamed: 325 -> 325
# Renamed: 326 -> 326
# Renamed: 327 -> 327
# Renamed: 328 -> 328
# Renamed: 329 -> 329
# Renamed: 330 -> 330
# Renamed: 331 -> 331
# Renamed: 332 -> 332
# Renamed: 333 -> 333
# Renamed: 334 -> 334
# Renamed: 335 -> 335
# Renamed: 336 -> 336
# Renamed: 337 -> 337
# Renamed: 338 -> 338
# Renamed: 339 -> 339
# Renamed: 340 -> 340
# Renamed: 341 -> 341
# Renamed: 342 -> 342
# Renamed: 343 -> 343
# Renamed: 344 -> 344
# Renamed: 345 -> 345
# Renamed: 346 -> 346
# Renamed: 347 -> 347
# Renamed: 348 -> 348
# Renamed: 349 -> 349
# Renamed: 350 -> 350
# Renamed: 351 -> 351
# Renamed: 352 -> 352
# Renamed: 353 -> 353
# Renamed: 354 -> 354
# Renamed: 355 -> 355
# Renamed: 356 -> 356
# Renamed: 357 -> 357
# Renamed: 358 -> 358
# Renamed: 359 -> 359
# Renamed: 360 -> 360
# Renamed: 361 -> 361
# Renamed: 362 -> 362
# Renamed: 363 -> 363
# Renamed: 364 -> 364
# Renamed: 365 -> 365
# Renamed: 366 -> 366
# Renamed: 367 -> 367
# Renamed: 368 -> 368
# Renamed: 369 -> 369
# Renamed: 370 -> 370
# Renamed: 371 -> 371
# Renamed: 372 -> 372
# Renamed: 373 -> 373
# Renamed: 374 -> 374
# Renamed: 375 -> 375
# Renamed: 376 -> 376
# Renamed: 377 -> 377
# Renamed: 378 -> 378
# Renamed: 379 -> 379
# Renamed: 380 -> 380
# Renamed: 381 -> 381
# Renamed: 382 -> 382
# Renamed: 383 -> 383
# Renamed: 384 -> 384
# Renamed: 385 -> 385
# Renamed: 386 -> 386
# Renamed: 387 -> 387
# Renamed: 388 -> 388
# Renamed: 389 -> 389
# Renamed: 390 -> 390
# Renamed: 391 -> 391
# Renamed: 392 -> 392
# Renamed: 393 -> 393
# Renamed: 394 -> 394
# Renamed: 395 -> 395
# Renamed: 396 -> 396
# Renamed: 397 -> 397
# Renamed: 398 -> 398
# Renamed: 399 -> 399
# Renamed: 400 -> 400
# Renamed: 401 -> 401
# Renamed: 402 -> 402
# Renamed: 403 -> 403
# Renamed: 404 -> 404
# Renamed: 405 -> 405
# Renamed: 406 -> 406
# Renamed: 407 -> 407
# Renamed: 408 -> 408
# Renamed: 409 -> 409
# Renamed: 410 -> 410
# Renamed: 411 -> 411
# Renamed: 412 -> 412
# Renamed: 414 -> 413
# Renamed: 415 -> 414
# Renamed: 416 -> 415
# Renamed: 417 -> 416
# Renamed: 418 -> 417
# Renamed: 419 -> 418
# Renamed: 420 -> 419
# Renamed: 421 -> 420
# Renamed: 422 -> 421
# Renamed: 423 -> 422
# Renamed: 424 -> 423
# Renamed: 425 -> 424
# Renamed: 426 -> 425
# Renamed: 427 -> 426
# Renamed: 428 -> 427
# Renamed: 429 -> 428
# Renamed: 430 -> 429
# Renamed: 431 -> 430
# Renamed: 432 -> 431
# Renamed: 433 -> 432
# Renamed: 434 -> 433
# Renamed: 435 -> 434
# Renamed: 436 -> 435
# Renamed: 437 -> 436
# Renamed: 438 -> 437
# Renamed: 439 -> 438
# Renamed: 440 -> 439
# Renamed: 441 -> 440
# Renamed: 442 -> 441
# Renamed: 443 -> 442
# Renamed: 444 -> 443
# Renamed: 445 -> 444
# Renamed: 446 -> 445
# Renamed: 447 -> 446
# Renamed: 448 -> 447
# Renamed: 449 -> 448
# Renamed: 450 -> 449
# Renamed: 451 -> 450
# Renamed: 452 -> 451
# Renamed: 453 -> 452
# Renamed: 454 -> 453
# Renamed: 455 -> 454
# Renamed: 456 -> 455
# Renamed: 457 -> 456
# Renamed: 458 -> 457
# Renamed: 459 -> 458
# Renamed: 460 -> 459
# Renamed: 461 -> 460
# Renamed: 462 -> 461
# Renamed: 463 -> 462
# Renamed: 464 -> 463
# Renamed: 465 -> 464
# Renamed: 466 -> 465
# Renamed: 467 -> 466
# Renamed: 468 -> 467
# Renamed: 469 -> 468
# Renamed: 470 -> 469
# Renamed: 471 -> 470
# Renamed: 472 -> 471
# Renamed: 473 -> 472
# Renamed: 474 -> 473
# Renamed: 475 -> 474
# Renamed: 476 -> 475
# Renamed: 477 -> 476
# Renamed: 478 -> 477
# Renamed: 479 -> 478
# Renamed: 480 -> 479
# Renamed: 481 -> 480
# Renamed: 482 -> 481
# Renamed: 483 -> 482
# Renamed: 484 -> 483
# Renamed: 485 -> 484
# Renamed: 486 -> 485
# Renamed: 487 -> 486
# Renamed: 488 -> 487
# Renamed: 489 -> 488
# Renamed: 490 -> 489
# Renamed: 491 -> 490
# Renamed: 492 -> 491
# Renamed: 493 -> 492
# Renamed: 494 -> 493
# Renamed: 495 -> 494
# Renamed: 496 -> 495
# Renamed: 497 -> 496
# Renamed: 498 -> 497
# Renamed: 499 -> 498
# Renamed: 500 -> 499
# Renamed: 501 -> 500
# Renamed: 502 -> 501
# Renamed: 503 -> 502
# Renamed: 504 -> 503
# Renamed: 505 -> 504
# Renamed: 506 -> 505
# Renamed: 507 -> 506
# Renamed: 508 -> 507
# Renamed: 509 -> 508
# Renamed: 510 -> 509
# Renamed: 511 -> 510
# Renamed: 512 -> 511
# Renamed: 513 -> 512
# Renamed: 514 -> 513
# Renamed: 515 -> 514
# Renamed: 516 -> 515
# Renamed: 517 -> 516
# Renamed: 518 -> 517
# Renamed: 519 -> 518
# Renamed: 520 -> 519
# Renamed: 521 -> 520
# Renamed: 522 -> 521
# Renamed: 523 -> 522
# Renamed: 524 -> 523
# Renamed: 525 -> 524
# Renamed: 526 -> 525
# Renamed: 527 -> 526
# Renamed: 528 -> 527
# Renamed: 529 -> 528
# Renamed: 530 -> 529
# Renamed: 531 -> 530
# Renamed: 532 -> 531
# Renamed: 533 -> 532
# Renamed: 534 -> 533
# Renamed: 535 -> 534
# Renamed: 536 -> 535
# Renamed: 537 -> 536
# Renamed: 538 -> 537
# Renamed: 539 -> 538
# Renamed: 540 -> 539
# Renamed: 541 -> 540
# Renamed: 542 -> 541
# Renamed: 543 -> 542
# Renamed: 544 -> 543
# Renamed: 545 -> 544
# Renamed: 546 -> 545
# Renamed: 547 -> 546
# Renamed: 548 -> 547
# Renamed: 549 -> 548
# Renamed: 550 -> 549
# Renamed: 551 -> 550
# Renamed: 552 -> 551
# Renamed: 553 -> 552
# Renamed: 554 -> 553
# Renamed: 555 -> 554
# Renamed: 556 -> 555
# Renamed: 557 -> 556
# Renamed: 558 -> 557
# Renamed: 559 -> 558
# Renamed: 560 -> 559
# Renamed: 561 -> 560
# Renamed: 562 -> 561
# Renamed: 563 -> 562

# %%
root = "quadrant_dataset"
file_ending = 'png'
file_name = "data_out.csv"
destination = "quadrant_diff"

for i in range(len(os.listdir(root))):
    directory = i + 1
    print("Processing directory", directory)
    if not os.path.exists(f"{destination}/{str(directory)}"):
        os.makedirs(f"{destination}/{str(directory)}")
        
    csv_file_name = f"{root}/{str(directory)}/{file_name}"
    labels = np.genfromtxt(csv_file_name, delimiter=',', skip_header=1, dtype=np.float32)
    
    image_files = [fn for fn in os.listdir(f"./{root}/{str(directory)}") if file_ending in fn]
    n_images = len(image_files)

    # Load the goal images
    goal_image = cv2.imread(f'{root}/{str(directory)}/Image{n_images}.png')

    for i in range(1, n_images + 1):
        # Load the current image
        current_image = cv2.imread(f'{root}/{str(directory)}/Image{i}.png')

        # Compute the absolute difference between the images
        difference = cv2.absdiff(current_image, goal_image)

        # Save the result
        cv2.imwrite(f'{destination}/{str(directory)}/Image{i}.png', difference)
    
    columns = ['vx', 'vy', 'vz', 'omega_z']
    df = pd.DataFrame(labels, columns=columns)
    df.to_csv(f"{destination}/{directory}/{file_name}", index=False)
# Out:
# Processing directory 1
# Processing directory 2
# Processing directory 3
# Processing directory 4
# Processing directory 5
# Processing directory 6
# Processing directory 7
# Processing directory 8
# Processing directory 9
# Processing directory 10
# Processing directory 11
# Processing directory 12
# Processing directory 13
# Processing directory 14
# Processing directory 15
# Processing directory 16
# Processing directory 17
# Processing directory 18
# Processing directory 19
# Processing directory 20
# Processing directory 21
# Processing directory 22
# Processing directory 23
# Processing directory 24
# Processing directory 25
# Processing directory 26
# Processing directory 27
# Processing directory 28
# Processing directory 29
# Processing directory 30
# Processing directory 31
# Processing directory 32
# Processing directory 33
# Processing directory 34
# Processing directory 35
# Processing directory 36
# Processing directory 37
# Processing directory 38
# Processing directory 39
# Processing directory 40
# Processing directory 41
# Processing directory 42
# Processing directory 43
# Processing directory 44
# Processing directory 45
# Processing directory 46
# Processing directory 47
# Processing directory 48
# Processing directory 49
# Processing directory 50
# Processing directory 51
# Processing directory 52
# Processing directory 53
# Processing directory 54
# Processing directory 55
# Processing directory 56
# Processing directory 57
# Processing directory 58
# Processing directory 59
# Processing directory 60
# Processing directory 61
# Processing directory 62
# Processing directory 63
# Processing directory 64
# Processing directory 65
# Processing directory 66
# Processing directory 67
# Processing directory 68
# Processing directory 69
# Processing directory 70
# Processing directory 71
# Processing directory 72
# Processing directory 73
# Processing directory 74
# Processing directory 75
# Processing directory 76
# Processing directory 77
# Processing directory 78
# Processing directory 79
# Processing directory 80
# Processing directory 81
# Processing directory 82
# Processing directory 83
# Processing directory 84
# Processing directory 85
# Processing directory 86
# Processing directory 87
# Processing directory 88
# Processing directory 89
# Processing directory 90
# Processing directory 91
# Processing directory 92
# Processing directory 93
# Processing directory 94
# Processing directory 95
# Processing directory 96
# Processing directory 97
# Processing directory 98
# Processing directory 99
# Processing directory 100
# Processing directory 101
# Processing directory 102
# Processing directory 103
# Processing directory 104
# Processing directory 105
# Processing directory 106
# Processing directory 107
# Processing directory 108
# Processing directory 109
# Processing directory 110
# Processing directory 111
# Processing directory 112
# Processing directory 113
# Processing directory 114
# Processing directory 115
# Processing directory 116
# Processing directory 117
# Processing directory 118
# Processing directory 119
# Processing directory 120
# Processing directory 121
# Processing directory 122
# Processing directory 123
# Processing directory 124
# Processing directory 125
# Processing directory 126
# Processing directory 127
# Processing directory 128
# Processing directory 129
# Processing directory 130
# Processing directory 131
# Processing directory 132
# Processing directory 133
# Processing directory 134
# Processing directory 135
# Processing directory 136
# Processing directory 137
# Processing directory 138
# Processing directory 139
# Processing directory 140
# Processing directory 141
# Processing directory 142
# Processing directory 143
# Processing directory 144
# Processing directory 145
# Processing directory 146
# Processing directory 147
# Processing directory 148
# Processing directory 149
# Processing directory 150
# Processing directory 151
# Processing directory 152
# Processing directory 153
# Processing directory 154
# Processing directory 155
# Processing directory 156
# Processing directory 157
# Processing directory 158
# Processing directory 159
# Processing directory 160
# Processing directory 161
# Processing directory 162
# Processing directory 163
# Processing directory 164
# Processing directory 165
# Processing directory 166
# Processing directory 167
# Processing directory 168
# Processing directory 169
# Processing directory 170
# Processing directory 171
# Processing directory 172
# Processing directory 173
# Processing directory 174
# Processing directory 175
# Processing directory 176
# Processing directory 177
# Processing directory 178
# Processing directory 179
# Processing directory 180
# Processing directory 181
# Processing directory 182
# Processing directory 183
# Processing directory 184
# Processing directory 185
# Processing directory 186
# Processing directory 187
# Processing directory 188
# Processing directory 189
# Processing directory 190
# Processing directory 191
# Processing directory 192
# Processing directory 193
# Processing directory 194
# Processing directory 195
# Processing directory 196
# Processing directory 197
# Processing directory 198
# Processing directory 199
# Processing directory 200
# Processing directory 201
# Processing directory 202
# Processing directory 203
# Processing directory 204
# Processing directory 205
# Processing directory 206
# Processing directory 207
# Processing directory 208
# Processing directory 209
# Processing directory 210
# Processing directory 211
# Processing directory 212
# Processing directory 213
# Processing directory 214
# Processing directory 215
# Processing directory 216
# Processing directory 217
# Processing directory 218
# Processing directory 219
# Processing directory 220
# Processing directory 221
# Processing directory 222
# Processing directory 223
# Processing directory 224
# Processing directory 225
# Processing directory 226
# Processing directory 227
# Processing directory 228
# Processing directory 229
# Processing directory 230
# Processing directory 231
# Processing directory 232
# Processing directory 233
# Processing directory 234
# Processing directory 235
# Processing directory 236
# Processing directory 237
# Processing directory 238
# Processing directory 239
# Processing directory 240
# Processing directory 241
# Processing directory 242
# Processing directory 243
# Processing directory 244
# Processing directory 245
# Processing directory 246
# Processing directory 247
# Processing directory 248
# Processing directory 249
# Processing directory 250
# Processing directory 251
# Processing directory 252
# Processing directory 253
# Processing directory 254
# Processing directory 255
# Processing directory 256
# Processing directory 257
# Processing directory 258
# Processing directory 259
# Processing directory 260
# Processing directory 261
# Processing directory 262
# Processing directory 263
# Processing directory 264
# Processing directory 265
# Processing directory 266
# Processing directory 267
# Processing directory 268
# Processing directory 269
# Processing directory 270
# Processing directory 271
# Processing directory 272
# Processing directory 273
# Processing directory 274
# Processing directory 275
# Processing directory 276
# Processing directory 277
# Processing directory 278
# Processing directory 279
# Processing directory 280
# Processing directory 281
# Processing directory 282
# Processing directory 283
# Processing directory 284
# Processing directory 285
# Processing directory 286
# Processing directory 287
# Processing directory 288
# Processing directory 289
# Processing directory 290
# Processing directory 291
# Processing directory 292
# Processing directory 293
# Processing directory 294
# Processing directory 295
# Processing directory 296
# Processing directory 297
# Processing directory 298
# Processing directory 299
# Processing directory 300
# Processing directory 301
# Processing directory 302
# Processing directory 303
# Processing directory 304
# Processing directory 305
# Processing directory 306
# Processing directory 307
# Processing directory 308
# Processing directory 309
# Processing directory 310
# Processing directory 311
# Processing directory 312
# Processing directory 313
# Processing directory 314
# Processing directory 315
# Processing directory 316
# Processing directory 317
# Processing directory 318
# Processing directory 319
# Processing directory 320
# Processing directory 321
# Processing directory 322
# Processing directory 323
# Processing directory 324
# Processing directory 325
# Processing directory 326
# Processing directory 327
# Processing directory 328
# Processing directory 329
# Processing directory 330
# Processing directory 331
# Processing directory 332
# Processing directory 333
# Processing directory 334
# Processing directory 335
# Processing directory 336
# Processing directory 337
# Processing directory 338
# Processing directory 339
# Processing directory 340
# Processing directory 341
# Processing directory 342
# Processing directory 343
# Processing directory 344
# Processing directory 345
# Processing directory 346
# Processing directory 347
# Processing directory 348
# Processing directory 349
# Processing directory 350
# Processing directory 351
# Processing directory 352
# Processing directory 353
# Processing directory 354
# Processing directory 355
# Processing directory 356
# Processing directory 357
# Processing directory 358
# Processing directory 359
# Processing directory 360
# Processing directory 361
# Processing directory 362
# Processing directory 363
# Processing directory 364
# Processing directory 365
# Processing directory 366
# Processing directory 367
# Processing directory 368
# Processing directory 369
# Processing directory 370
# Processing directory 371
# Processing directory 372
# Processing directory 373
# Processing directory 374
# Processing directory 375
# Processing directory 376
# Processing directory 377
# Processing directory 378
# Processing directory 379
# Processing directory 380
# Processing directory 381
# Processing directory 382
# Processing directory 383
# Processing directory 384
# Processing directory 385
# Processing directory 386
# Processing directory 387
# Processing directory 388
# Processing directory 389
# Processing directory 390
# Processing directory 391
# Processing directory 392
# Processing directory 393
# Processing directory 394
# Processing directory 395
# Processing directory 396
# Processing directory 397
# Processing directory 398
# Processing directory 399
# Processing directory 400
# Processing directory 401
# Processing directory 402
# Processing directory 403
# Processing directory 404
# Processing directory 405
# Processing directory 406
# Processing directory 407
# Processing directory 408
# Processing directory 409
# Processing directory 410
# Processing directory 411
# Processing directory 412
# Processing directory 413
# Processing directory 414
# Processing directory 415
# Processing directory 416
# Processing directory 417
# Processing directory 418
# Processing directory 419
# Processing directory 420
# Processing directory 421
# Processing directory 422
# Processing directory 423
# Processing directory 424
# Processing directory 425
# Processing directory 426
# Processing directory 427
# Processing directory 428
# Processing directory 429
# Processing directory 430
# Processing directory 431
# Processing directory 432
# Processing directory 433
# Processing directory 434
# Processing directory 435
# Processing directory 436
# Processing directory 437
# Processing directory 438
# Processing directory 439
# Processing directory 440
# Processing directory 441
# Processing directory 442
# Processing directory 443
# Processing directory 444
# Processing directory 445
# Processing directory 446
# Processing directory 447
# Processing directory 448
# Processing directory 449
# Processing directory 450
# Processing directory 451
# Processing directory 452
# Processing directory 453
# Processing directory 454
# Processing directory 455
# Processing directory 456
# Processing directory 457
# Processing directory 458
# Processing directory 459
# Processing directory 460
# Processing directory 461
# Processing directory 462
# Processing directory 463
# Processing directory 464
# Processing directory 465
# Processing directory 466
# Processing directory 467
# Processing directory 468
# Processing directory 469
# Processing directory 470
# Processing directory 471
# Processing directory 472
# Processing directory 473
# Processing directory 474
# Processing directory 475
# Processing directory 476
# Processing directory 477
# Processing directory 478
# Processing directory 479
# Processing directory 480
# Processing directory 481
# Processing directory 482
# Processing directory 483
# Processing directory 484
# Processing directory 485
# Processing directory 486
# Processing directory 487
# Processing directory 488
# Processing directory 489
# Processing directory 490
# Processing directory 491
# Processing directory 492
# Processing directory 493
# Processing directory 494
# Processing directory 495
# Processing directory 496
# Processing directory 497
# Processing directory 498
# Processing directory 499
# Processing directory 500
# Processing directory 501
# Processing directory 502
# Processing directory 503
# Processing directory 504
# Processing directory 505
# Processing directory 506
# Processing directory 507
# Processing directory 508
# Processing directory 509
# Processing directory 510
# Processing directory 511
# Processing directory 512
# Processing directory 513
# Processing directory 514
# Processing directory 515
# Processing directory 516
# Processing directory 517
# Processing directory 518
# Processing directory 519
# Processing directory 520
# Processing directory 521
# Processing directory 522
# Processing directory 523
# Processing directory 524
# Processing directory 525
# Processing directory 526
# Processing directory 527
# Processing directory 528
# Processing directory 529
# Processing directory 530
# Processing directory 531
# Processing directory 532
# Processing directory 533
# Processing directory 534
# Processing directory 535
# Processing directory 536
# Processing directory 537
# Processing directory 538
# Processing directory 539
# Processing directory 540
# Processing directory 541
# Processing directory 542
# Processing directory 543
# Processing directory 544
# Processing directory 545
# Processing directory 546
# Processing directory 547
# Processing directory 548
# Processing directory 549
# Processing directory 550
# Processing directory 551
# Processing directory 552
# Processing directory 553
# Processing directory 554
# Processing directory 555
# Processing directory 556
# Processing directory 557
# Processing directory 558
# Processing directory 559
# Processing directory 560
# Processing directory 561
# Processing directory 562
