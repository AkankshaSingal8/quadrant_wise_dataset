# %%
import os
from typing import Iterable, Dict

import csv

import numpy as np
from matplotlib.image import imread
from tqdm import tqdm
from PIL import Image

import seaborn as sns
import pandas as pd
import scipy.io

import cv2

# %%
# !pwd
# Out:
# /src/drone_causality/quadrant_wise_dataset

# %%
# CONVERTING MAT TO CSV FILE 
def mat_to_csv(dataset_directory):

    # Iterate through directories in the dataset directory
    for i in range(len(os.listdir(dataset_directory))):
        directory = os.path.join(dataset_directory, str(i + 1))
        csv_file_path = os.path.join(directory, 'data_out.csv')
        
        # Check if the directory exists and data_out.csv does not exist
        if os.path.exists(directory) and (not os.path.exists(csv_file_path)):
            mat_file_path = os.path.join(directory, 'Vel.mat')

            # Check if the Vel.mat file exists in the directory
            if os.path.exists(mat_file_path):
                # Load the .mat file
                data = scipy.io.loadmat(mat_file_path)
                df = pd.DataFrame(data['V'], columns=['vx', 'vy', 'vz', 'omega_z'])
                print(len(df))

                # Save to CSV in the same directory
                df.to_csv(csv_file_path, index=False)

            else:
                print(f"'Vel.mat' file not found in {directory}")
        else:
            print(f"Directory {directory} does not exist or 'data_out.csv' already exists in directory {directory}")

# %%
# Directory containing the datasets
dataset_directory = 'goal_height_5' 

mat_to_csv(dataset_directory)

# %%
# 30 % of each trajecrory as hovering 

root = "goal_height_5"
file_ending = 'png'
file_name = "data_out.csv"

for i in range(0, len(os.listdir(root))):
    directory = i + 1
    print("Processing directory", directory)

    csv_file_name = f"{root}/{str(directory)}/{file_name}"
    labels = np.genfromtxt(csv_file_name, delimiter=',', skip_header=1, dtype=np.float32)
    diff = int((30 * len(labels))/100)
    print("diff_labels", diff)
    print("labels len", labels.shape)
    
    velocity_values = [0.0, 0.0, 0.0, 0.0]
    
    with open(csv_file_name, 'a', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        for i in range(diff):
            csvwriter.writerow(velocity_values)
   

    n_images = len([fn for fn in os.listdir(f"./{root}/{str(directory)}") if file_ending in fn])
    print("Number of images:", n_images)
    
    img_file_name = f"{root}/{str(directory)}/Image{str(n_images)}.png"
    img = Image.open(img_file_name)
    for i in range(1, diff + 1):
       
        new_filename = os.path.join(root,str(directory))
        fname =  f"Image{str(i + n_images)}.png"
        file_path = os.path.join(new_filename, fname)
        
        img.save(file_path)
# Out:
# Processing directory 1
# diff_labels 37
# labels len (124, 4)
# Number of images: 124
# Processing directory 2
# diff_labels 164
# labels len (549, 4)
# Number of images: 549
# Processing directory 3
# diff_labels 138
# labels len (462, 4)
# Number of images: 462
# Processing directory 4
# diff_labels 123
# labels len (411, 4)
# Number of images: 411
# Processing directory 5
# diff_labels 95
# labels len (319, 4)
# Number of images: 319
# Processing directory 6
# diff_labels 157
# labels len (524, 4)
# Number of images: 524
# Processing directory 7
# diff_labels 129
# labels len (430, 4)
# Number of images: 430
# Processing directory 8
# diff_labels 175
# labels len (586, 4)
# Number of images: 586
# Processing directory 9
# diff_labels 96
# labels len (320, 4)
# Number of images: 320
# Processing directory 10
# diff_labels 154
# labels len (516, 4)
# Number of images: 516
# Processing directory 11
# diff_labels 105
# labels len (353, 4)
# Number of images: 353
# Processing directory 12
# diff_labels 156
# labels len (522, 4)
# Number of images: 522
# Processing directory 13
# diff_labels 153
# labels len (510, 4)
# Number of images: 510
# Processing directory 14
# diff_labels 37
# labels len (125, 4)
# Number of images: 125
# Processing directory 15
# diff_labels 151
# labels len (504, 4)
# Number of images: 504
# Processing directory 16
# diff_labels 94
# labels len (315, 4)
# Number of images: 315
# Processing directory 17
# diff_labels 157
# labels len (526, 4)
# Number of images: 526
# Processing directory 18
# diff_labels 105
# labels len (352, 4)
# Number of images: 352
# Processing directory 19
# diff_labels 150
# labels len (503, 4)
# Number of images: 503
# Processing directory 20
# diff_labels 128
# labels len (429, 4)
# Number of images: 429
# Processing directory 21
# diff_labels 157
# labels len (524, 4)
# Number of images: 524
# Processing directory 22
# diff_labels 87
# labels len (290, 4)
# Number of images: 290
# Processing directory 23
# diff_labels 165
# labels len (551, 4)
# Number of images: 551
# Processing directory 24
# diff_labels 158
# labels len (528, 4)
# Number of images: 528
# Processing directory 25
# diff_labels 105
# labels len (353, 4)
# Number of images: 353
# Processing directory 26
# diff_labels 105
# labels len (352, 4)
# Number of images: 352
# Processing directory 27
# diff_labels 94
# labels len (316, 4)
# Number of images: 316
# Processing directory 28
# diff_labels 94
# labels len (316, 4)
# Number of images: 316
# Processing directory 29
# diff_labels 152
# labels len (507, 4)
# Number of images: 507
# Processing directory 30
# diff_labels 166
# labels len (555, 4)
# Number of images: 555
# Processing directory 31
# diff_labels 95
# labels len (317, 4)
# Number of images: 317
# Processing directory 32
# diff_labels 96
# labels len (320, 4)
# Number of images: 320
# Processing directory 33
# diff_labels 122
# labels len (408, 4)
# Number of images: 408
# Processing directory 34
# diff_labels 94
# labels len (316, 4)
# Number of images: 316
# Processing directory 35
# diff_labels 150
# labels len (502, 4)
# Number of images: 502
# Processing directory 36
# diff_labels 96
# labels len (320, 4)
# Number of images: 320
# Processing directory 37
# diff_labels 156
# labels len (521, 4)
# Number of images: 521
# Processing directory 38
# diff_labels 137
# labels len (459, 4)
# Number of images: 459
# Processing directory 39
# diff_labels 151
# labels len (506, 4)
# Number of images: 506
# Processing directory 40
# diff_labels 114
# labels len (382, 4)
# Number of images: 382
# Processing directory 41
# diff_labels 102
# labels len (343, 4)
# Number of images: 343
# Processing directory 42
# diff_labels 154
# labels len (516, 4)
# Number of images: 516
# Processing directory 43
# diff_labels 143
# labels len (477, 4)
# Number of images: 477
# Processing directory 44
# diff_labels 94
# labels len (316, 4)
# Number of images: 316
# Processing directory 45
# diff_labels 150
# labels len (502, 4)
# Number of images: 502
# Processing directory 46
# diff_labels 151
# labels len (504, 4)
# Number of images: 504
# Processing directory 47
# diff_labels 157
# labels len (525, 4)
# Number of images: 525
# Processing directory 48
# diff_labels 177
# labels len (590, 4)
# Number of images: 590
# Processing directory 49
# diff_labels 102
# labels len (342, 4)
# Number of images: 342
# Processing directory 50
# diff_labels 151
# labels len (506, 4)
# Number of images: 506
# Processing directory 51
# diff_labels 123
# labels len (411, 4)
# Number of images: 411
# Processing directory 52
# diff_labels 95
# labels len (319, 4)
# Number of images: 319
# Processing directory 53
# diff_labels 165
# labels len (553, 4)
# Number of images: 553
# Processing directory 54
# diff_labels 115
# labels len (384, 4)
# Number of images: 384
# Processing directory 55
# diff_labels 122
# labels len (408, 4)
# Number of images: 408
# Processing directory 56
# diff_labels 102
# labels len (343, 4)
# Number of images: 343
# Processing directory 57
# diff_labels 102
# labels len (341, 4)
# Number of images: 341
# Processing directory 58
# diff_labels 102
# labels len (341, 4)
# Number of images: 341
# Processing directory 59
# diff_labels 101
# labels len (338, 4)
# Number of images: 338
# Processing directory 60
# diff_labels 123
# labels len (411, 4)
# Number of images: 411
# Processing directory 61
# diff_labels 114
# labels len (381, 4)
# Number of images: 381
# Processing directory 62
# diff_labels 102
# labels len (343, 4)
# Number of images: 343
# Processing directory 63
# diff_labels 137
# labels len (458, 4)
# Number of images: 458
# Processing directory 64
# diff_labels 122
# labels len (408, 4)
# Number of images: 408
# Processing directory 65
# diff_labels 101
# labels len (338, 4)
# Number of images: 338
# Processing directory 66
# diff_labels 102
# labels len (342, 4)
# Number of images: 342
# Processing directory 67
# diff_labels 114
# labels len (382, 4)
# Number of images: 382
# Processing directory 68
# diff_labels 94
# labels len (314, 4)
# Number of images: 314
# Processing directory 69
# diff_labels 138
# labels len (462, 4)
# Number of images: 462
# Processing directory 70
# diff_labels 122
# labels len (409, 4)
# Number of images: 409
# Processing directory 71
# diff_labels 102
# labels len (342, 4)
# Number of images: 342
# Processing directory 72
# diff_labels 115
# labels len (384, 4)
# Number of images: 384
# Processing directory 73
# diff_labels 102
# labels len (343, 4)
# Number of images: 343
# Processing directory 74
# diff_labels 102
# labels len (341, 4)
# Number of images: 341
# Processing directory 75
# diff_labels 102
# labels len (342, 4)
# Number of images: 342

# %%
# trajectory length as a factor of 64

root = "goal_height_5"
file_ending = 'png'
file_name = "data_out.csv"

for i in range(0, len(os.listdir(root))):
    directory = i + 1
    print("Processing directory", directory)

    csv_file_name = f"{root}/{str(directory)}/{file_name}"
    labels = np.genfromtxt(csv_file_name, delimiter=',', skip_header=1, dtype=np.float32)
    
    d = labels.shape[0]%64
    if d == 0:
        diff_labels = 0
    else:
        diff_labels = 64 - d
 
    # print("labels", labels[-1])
    velocity_values = [0.0, 0.0, 0.0, 0.0]
    
    with open(csv_file_name, 'a', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        for i in range(diff_labels):
            csvwriter.writerow(velocity_values)
   

   
    n_images = len([fn for fn in os.listdir(f"./{root}/{str(directory)}") if file_ending in fn])
    print("Number of images:", n_images)
  
    d_img = n_images % 64
    
    if d_img == 0:
        diff = 0
    else:
        diff = 64 - d_img
    print("diff_labels", diff_labels, " diff", diff, " diff_labels%64", (labels.shape[0] + diff_labels)%64, " diff%64", (n_images + diff)%64)
    
    img_file_name = f"{root}/{str(directory)}/Image{str(n_images)}.png"
    img = Image.open(img_file_name)
    for i in range(1, diff + 1):
       
        new_filename = os.path.join(root,str(directory))
        fname =  f"Image{str(i + n_images)}.png"
        file_path = os.path.join(new_filename, fname)
        
        img.save(file_path)
# Out:
# Processing directory 1
# Number of images: 161
# diff_labels 31  diff 31  diff_labels%64 0  diff%64 0
# Processing directory 2
# Number of images: 713
# diff_labels 55  diff 55  diff_labels%64 0  diff%64 0
# Processing directory 3
# Number of images: 600
# diff_labels 40  diff 40  diff_labels%64 0  diff%64 0
# Processing directory 4
# Number of images: 534
# diff_labels 42  diff 42  diff_labels%64 0  diff%64 0
# Processing directory 5
# Number of images: 414
# diff_labels 34  diff 34  diff_labels%64 0  diff%64 0
# Processing directory 6
# Number of images: 681
# diff_labels 23  diff 23  diff_labels%64 0  diff%64 0
# Processing directory 7
# Number of images: 559
# diff_labels 17  diff 17  diff_labels%64 0  diff%64 0
# Processing directory 8
# Number of images: 761
# diff_labels 7  diff 7  diff_labels%64 0  diff%64 0
# Processing directory 9
# Number of images: 416
# diff_labels 32  diff 32  diff_labels%64 0  diff%64 0
# Processing directory 10
# Number of images: 670
# diff_labels 34  diff 34  diff_labels%64 0  diff%64 0
# Processing directory 11
# Number of images: 458
# diff_labels 54  diff 54  diff_labels%64 0  diff%64 0
# Processing directory 12
# Number of images: 678
# diff_labels 26  diff 26  diff_labels%64 0  diff%64 0
# Processing directory 13
# Number of images: 663
# diff_labels 41  diff 41  diff_labels%64 0  diff%64 0
# Processing directory 14
# Number of images: 162
# diff_labels 30  diff 30  diff_labels%64 0  diff%64 0
# Processing directory 15
# Number of images: 655
# diff_labels 49  diff 49  diff_labels%64 0  diff%64 0
# Processing directory 16
# Number of images: 409
# diff_labels 39  diff 39  diff_labels%64 0  diff%64 0
# Processing directory 17
# Number of images: 683
# diff_labels 21  diff 21  diff_labels%64 0  diff%64 0
# Processing directory 18
# Number of images: 457
# diff_labels 55  diff 55  diff_labels%64 0  diff%64 0
# Processing directory 19
# Number of images: 653
# diff_labels 51  diff 51  diff_labels%64 0  diff%64 0
# Processing directory 20
# Number of images: 557
# diff_labels 19  diff 19  diff_labels%64 0  diff%64 0
# Processing directory 21
# Number of images: 681
# diff_labels 23  diff 23  diff_labels%64 0  diff%64 0
# Processing directory 22
# Number of images: 377
# diff_labels 7  diff 7  diff_labels%64 0  diff%64 0
# Processing directory 23
# Number of images: 716
# diff_labels 52  diff 52  diff_labels%64 0  diff%64 0
# Processing directory 24
# Number of images: 686
# diff_labels 18  diff 18  diff_labels%64 0  diff%64 0
# Processing directory 25
# Number of images: 458
# diff_labels 54  diff 54  diff_labels%64 0  diff%64 0
# Processing directory 26
# Number of images: 457
# diff_labels 55  diff 55  diff_labels%64 0  diff%64 0
# Processing directory 27
# Number of images: 410
# diff_labels 38  diff 38  diff_labels%64 0  diff%64 0
# Processing directory 28
# Number of images: 410
# diff_labels 38  diff 38  diff_labels%64 0  diff%64 0
# Processing directory 29
# Number of images: 659
# diff_labels 45  diff 45  diff_labels%64 0  diff%64 0
# Processing directory 30
# Number of images: 721
# diff_labels 47  diff 47  diff_labels%64 0  diff%64 0
# Processing directory 31
# Number of images: 412
# diff_labels 36  diff 36  diff_labels%64 0  diff%64 0
# Processing directory 32
# Number of images: 416
# diff_labels 32  diff 32  diff_labels%64 0  diff%64 0
# Processing directory 33
# Number of images: 530
# diff_labels 46  diff 46  diff_labels%64 0  diff%64 0
# Processing directory 34
# Number of images: 410
# diff_labels 38  diff 38  diff_labels%64 0  diff%64 0
# Processing directory 35
# Number of images: 652
# diff_labels 52  diff 52  diff_labels%64 0  diff%64 0
# Processing directory 36
# Number of images: 416
# diff_labels 32  diff 32  diff_labels%64 0  diff%64 0
# Processing directory 37
# Number of images: 677
# diff_labels 27  diff 27  diff_labels%64 0  diff%64 0
# Processing directory 38
# Number of images: 596
# diff_labels 44  diff 44  diff_labels%64 0  diff%64 0
# Processing directory 39
# Number of images: 657
# diff_labels 47  diff 47  diff_labels%64 0  diff%64 0
# Processing directory 40
# Number of images: 496
# diff_labels 16  diff 16  diff_labels%64 0  diff%64 0
# Processing directory 41
# Number of images: 445
# diff_labels 3  diff 3  diff_labels%64 0  diff%64 0
# Processing directory 42
# Number of images: 670
# diff_labels 34  diff 34  diff_labels%64 0  diff%64 0
# Processing directory 43
# Number of images: 620
# diff_labels 20  diff 20  diff_labels%64 0  diff%64 0
# Processing directory 44
# Number of images: 410
# diff_labels 38  diff 38  diff_labels%64 0  diff%64 0
# Processing directory 45
# Number of images: 652
# diff_labels 52  diff 52  diff_labels%64 0  diff%64 0
# Processing directory 46
# Number of images: 655
# diff_labels 49  diff 49  diff_labels%64 0  diff%64 0
# Processing directory 47
# Number of images: 682
# diff_labels 22  diff 22  diff_labels%64 0  diff%64 0
# Processing directory 48
# Number of images: 767
# diff_labels 1  diff 1  diff_labels%64 0  diff%64 0
# Processing directory 49
# Number of images: 444
# diff_labels 4  diff 4  diff_labels%64 0  diff%64 0
# Processing directory 50
# Number of images: 657
# diff_labels 47  diff 47  diff_labels%64 0  diff%64 0
# Processing directory 51
# Number of images: 534
# diff_labels 42  diff 42  diff_labels%64 0  diff%64 0
# Processing directory 52
# Number of images: 414
# diff_labels 34  diff 34  diff_labels%64 0  diff%64 0
# Processing directory 53
# Number of images: 718
# diff_labels 50  diff 50  diff_labels%64 0  diff%64 0
# Processing directory 54
# Number of images: 499
# diff_labels 13  diff 13  diff_labels%64 0  diff%64 0
# Processing directory 55
# Number of images: 530
# diff_labels 46  diff 46  diff_labels%64 0  diff%64 0
# Processing directory 56
# Number of images: 445
# diff_labels 3  diff 3  diff_labels%64 0  diff%64 0
# Processing directory 57
# Number of images: 443
# diff_labels 5  diff 5  diff_labels%64 0  diff%64 0
# Processing directory 58
# Number of images: 443
# diff_labels 5  diff 5  diff_labels%64 0  diff%64 0
# Processing directory 59
# Number of images: 439
# diff_labels 9  diff 9  diff_labels%64 0  diff%64 0
# Processing directory 60
# Number of images: 534
# diff_labels 42  diff 42  diff_labels%64 0  diff%64 0
# Processing directory 61
# Number of images: 495
# diff_labels 17  diff 17  diff_labels%64 0  diff%64 0
# Processing directory 62
# Number of images: 445
# diff_labels 3  diff 3  diff_labels%64 0  diff%64 0
# Processing directory 63
# Number of images: 595
# diff_labels 45  diff 45  diff_labels%64 0  diff%64 0
# Processing directory 64
# Number of images: 530
# diff_labels 46  diff 46  diff_labels%64 0  diff%64 0
# Processing directory 65
# Number of images: 439
# diff_labels 9  diff 9  diff_labels%64 0  diff%64 0
# Processing directory 66
# Number of images: 444
# diff_labels 4  diff 4  diff_labels%64 0  diff%64 0
# Processing directory 67
# Number of images: 496
# diff_labels 16  diff 16  diff_labels%64 0  diff%64 0
# Processing directory 68
# Number of images: 408
# diff_labels 40  diff 40  diff_labels%64 0  diff%64 0
# Processing directory 69
# Number of images: 600
# diff_labels 40  diff 40  diff_labels%64 0  diff%64 0
# Processing directory 70
# Number of images: 531
# diff_labels 45  diff 45  diff_labels%64 0  diff%64 0
# Processing directory 71
# Number of images: 444
# diff_labels 4  diff 4  diff_labels%64 0  diff%64 0
# Processing directory 72
# Number of images: 499
# diff_labels 13  diff 13  diff_labels%64 0  diff%64 0
# Processing directory 73
# Number of images: 445
# diff_labels 3  diff 3  diff_labels%64 0  diff%64 0
# Processing directory 74
# Number of images: 443
# diff_labels 5  diff 5  diff_labels%64 0  diff%64 0
# Processing directory 75
# Number of images: 444
# diff_labels 4  diff 4  diff_labels%64 0  diff%64 0

# %%
root = "goal_height_5"
file_ending = 'png'
file_name = "data_out.csv"

for i in range(0, len(os.listdir(root))):
    directory = i + 1
    print("Processing directory", directory)

    csv_file_name = f"{root}/{str(directory)}/{file_name}"
    labels = np.genfromtxt(csv_file_name, delimiter=',', skip_header=1, dtype=np.float32)
    
    d = labels.shape[0]%64
    if d == 0:
        diff_labels = 0
    else:
        diff_labels = 64 - d
 
    # print("labels", labels[-1])
    velocity_values = [0.0, 0.0, 0.0, 0.0]
    
    with open(csv_file_name, 'a', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        for i in range(diff_labels):
            csvwriter.writerow(velocity_values)
   

   
    n_images = len([fn for fn in os.listdir(f"./{root}/{str(directory)}") if file_ending in fn])
    print("Number of images:", n_images)
  
    d_img = n_images % 64
    
    if d_img == 0:
        diff = 0
    else:
        diff = 64 - d_img
    print("diff_labels", diff_labels, " diff", diff, " diff_labels%64", (labels.shape[0] + diff_labels)%64, " diff%64", (n_images + diff)%64)
    
    img_file_name = f"{root}/{str(directory)}/Image{str(n_images)}.png"
    img = Image.open(img_file_name)
    for i in range(1, diff + 1):
       
        new_filename = os.path.join(root,str(directory))
        fname =  f"Image{str(i + n_images)}.png"
        file_path = os.path.join(new_filename, fname)
        
        img.save(file_path)

# %%
# Creating sparse subset of the trajectory
root = "goal_height_5"
file_ending = 'png'
file_name = "data_out.csv"
length_root = len(os.listdir(root))

for i in range(len(os.listdir(root))):
    directory = i + 1
    print("Processing directory", directory)
    new_directory = length_root + directory
    print("Creating directory", new_directory)
    new_directory_path = f"{root}/{new_directory}"
    if not os.path.exists(new_directory_path):
        os.makedirs(new_directory_path)
        
   
    csv_file_name = f"{root}/{str(directory)}/{file_name}"
    labels = np.genfromtxt(csv_file_name, delimiter=',', skip_header=1, dtype=np.float32)

    image_files = [fn for fn in os.listdir(f"./{root}/{str(directory)}") if file_ending in fn]
    n_images = len(image_files)
    print("Number of images:", n_images)
    sorted_image_files = list(range(1, n_images + 1))

    # Select every 10th image
    selected_images_files = sorted_image_files[::10]
    selected_images_files = selected_images_files[:44]
    selected_images_files.extend([n_images] * 20)

    selected_labels = labels[::10].tolist()  
    selected_labels = selected_labels[:44]
    
    # print(len(selected_images_files), len(selected_labels))
    
    # last image
    
    velocity_values = [0.0, 0.0, 0.0, 0.0]
    selected_labels.extend([velocity_values] * 20)
    
    # print(selected_images_files, selected_labels)

    for i in range(len(selected_images_files)):
        image_file = selected_images_files[i]
        image_path = f"{root}/{str(directory)}/Image{str(image_file)}.png"
        img = Image.open(image_path)
       
        new_filename =  f"{root}/{new_directory}/Image{str(i + 1)}.png"
       
        img.save(new_filename)
    
    columns = ['vx', 'vy', 'vz', 'omega_z']
    df = pd.DataFrame(selected_labels, columns=columns)
    df.to_csv(f"{root}/{new_directory}/{file_name}", index=False)
# Out:
# Processing directory 1
# Creating directory 76
# Number of images: 192
# Processing directory 2
# Creating directory 77
# Number of images: 768
# Processing directory 3
# Creating directory 78
# Number of images: 640
# Processing directory 4
# Creating directory 79
# Number of images: 576
# Processing directory 5
# Creating directory 80
# Number of images: 448
# Processing directory 6
# Creating directory 81
# Number of images: 704
# Processing directory 7
# Creating directory 82
# Number of images: 576
# Processing directory 8
# Creating directory 83
# Number of images: 768
# Processing directory 9
# Creating directory 84
# Number of images: 448
# Processing directory 10
# Creating directory 85
# Number of images: 704
# Processing directory 11
# Creating directory 86
# Number of images: 512
# Processing directory 12
# Creating directory 87
# Number of images: 704
# Processing directory 13
# Creating directory 88
# Number of images: 704
# Processing directory 14
# Creating directory 89
# Number of images: 192
# Processing directory 15
# Creating directory 90
# Number of images: 704
# Processing directory 16
# Creating directory 91
# Number of images: 448
# Processing directory 17
# Creating directory 92
# Number of images: 704
# Processing directory 18
# Creating directory 93
# Number of images: 512
# Processing directory 19
# Creating directory 94
# Number of images: 704
# Processing directory 20
# Creating directory 95
# Number of images: 576
# Processing directory 21
# Creating directory 96
# Number of images: 704
# Processing directory 22
# Creating directory 97
# Number of images: 384
# Processing directory 23
# Creating directory 98
# Number of images: 768
# Processing directory 24
# Creating directory 99
# Number of images: 704
# Processing directory 25
# Creating directory 100
# Number of images: 512
# Processing directory 26
# Creating directory 101
# Number of images: 512
# Processing directory 27
# Creating directory 102
# Number of images: 448
# Processing directory 28
# Creating directory 103
# Number of images: 448
# Processing directory 29
# Creating directory 104
# Number of images: 704
# Processing directory 30
# Creating directory 105
# Number of images: 768
# Processing directory 31
# Creating directory 106
# Number of images: 448
# Processing directory 32
# Creating directory 107
# Number of images: 448
# Processing directory 33
# Creating directory 108
# Number of images: 576
# Processing directory 34
# Creating directory 109
# Number of images: 448
# Processing directory 35
# Creating directory 110
# Number of images: 704
# Processing directory 36
# Creating directory 111
# Number of images: 448
# Processing directory 37
# Creating directory 112
# Number of images: 704
# Processing directory 38
# Creating directory 113
# Number of images: 640
# Processing directory 39
# Creating directory 114
# Number of images: 704
# Processing directory 40
# Creating directory 115
# Number of images: 512
# Processing directory 41
# Creating directory 116
# Number of images: 448
# Processing directory 42
# Creating directory 117
# Number of images: 704
# Processing directory 43
# Creating directory 118
# Number of images: 640
# Processing directory 44
# Creating directory 119
# Number of images: 448
# Processing directory 45
# Creating directory 120
# Number of images: 704
# Processing directory 46
# Creating directory 121
# Number of images: 704
# Processing directory 47
# Creating directory 122
# Number of images: 704
# Processing directory 48
# Creating directory 123
# Number of images: 768
# Processing directory 49
# Creating directory 124
# Number of images: 448
# Processing directory 50
# Creating directory 125
# Number of images: 704
# Processing directory 51
# Creating directory 126
# Number of images: 576
# Processing directory 52
# Creating directory 127
# Number of images: 448
# Processing directory 53
# Creating directory 128
# Number of images: 768
# Processing directory 54
# Creating directory 129
# Number of images: 512
# Processing directory 55
# Creating directory 130
# Number of images: 576
# Processing directory 56
# Creating directory 131
# Number of images: 448
# Processing directory 57
# Creating directory 132
# Number of images: 448
# Processing directory 58
# Creating directory 133
# Number of images: 448
# Processing directory 59
# Creating directory 134
# Number of images: 448
# Processing directory 60
# Creating directory 135
# Number of images: 576
# Processing directory 61
# Creating directory 136
# Number of images: 512
# Processing directory 62
# Creating directory 137
# Number of images: 448
# Processing directory 63
# Creating directory 138
# Number of images: 640
# Processing directory 64
# Creating directory 139
# Number of images: 576
# Processing directory 65
# Creating directory 140
# Number of images: 448
# Processing directory 66
# Creating directory 141
# Number of images: 448
# Processing directory 67
# Creating directory 142
# Number of images: 512
# Processing directory 68
# Creating directory 143
# Number of images: 448
# Processing directory 69
# Creating directory 144
# Number of images: 640
# Processing directory 70
# Creating directory 145
# Number of images: 576
# Processing directory 71
# Creating directory 146
# Number of images: 448
# Processing directory 72
# Creating directory 147
# Number of images: 512
# Processing directory 73
# Creating directory 148
# Number of images: 448
# Processing directory 74
# Creating directory 149
# Number of images: 448
# Processing directory 75
# Creating directory 150
# Number of images: 448

# %%
# Checking if the dataset has no of velocity and images same

root = "goal_height_5"
file_ending = 'png'
file_name = "data_out.csv"

for i in range(len(os.listdir(root))):
    try:
        directory = i + 1
        print("Processing directory", directory)

        csv_file_name = f"{root}/{str(directory)}/{file_name}"
        labels = np.genfromtxt(csv_file_name, delimiter=',', skip_header=1, dtype=np.float32)
        

        image_files = [fn for fn in os.listdir(f"./{root}/{str(directory)}") if file_ending in fn]
        n_images = len(image_files)
        print(f"Number of labels: {len(labels)} Number of images: {n_images}")

        assert len(labels) == n_images and n_images >= 64, f"{directory}"
    except:
        pass
# Out:
# Processing directory 1
# Number of labels: 192 Number of images: 192
# Processing directory 2
# Number of labels: 768 Number of images: 768
# Processing directory 3
# Number of labels: 640 Number of images: 640
# Processing directory 4
# Number of labels: 576 Number of images: 576
# Processing directory 5
# Number of labels: 448 Number of images: 448
# Processing directory 6
# Number of labels: 704 Number of images: 704
# Processing directory 7
# Number of labels: 576 Number of images: 576
# Processing directory 8
# Number of labels: 768 Number of images: 768
# Processing directory 9
# Number of labels: 448 Number of images: 448
# Processing directory 10
# Number of labels: 704 Number of images: 704
# Processing directory 11
# Number of labels: 512 Number of images: 512
# Processing directory 12
# Number of labels: 704 Number of images: 704
# Processing directory 13
# Number of labels: 704 Number of images: 704
# Processing directory 14
# Number of labels: 192 Number of images: 192
# Processing directory 15
# Number of labels: 704 Number of images: 704
# Processing directory 16
# Number of labels: 448 Number of images: 448
# Processing directory 17
# Number of labels: 704 Number of images: 704
# Processing directory 18
# Number of labels: 512 Number of images: 512
# Processing directory 19
# Number of labels: 704 Number of images: 704
# Processing directory 20
# Number of labels: 576 Number of images: 576
# Processing directory 21
# Number of labels: 704 Number of images: 704
# Processing directory 22
# Number of labels: 384 Number of images: 384
# Processing directory 23
# Number of labels: 768 Number of images: 768
# Processing directory 24
# Number of labels: 704 Number of images: 704
# Processing directory 25
# Number of labels: 512 Number of images: 512
# Processing directory 26
# Number of labels: 512 Number of images: 512
# Processing directory 27
# Number of labels: 448 Number of images: 448
# Processing directory 28
# Number of labels: 448 Number of images: 448
# Processing directory 29
# Number of labels: 704 Number of images: 704
# Processing directory 30
# Number of labels: 768 Number of images: 768
# Processing directory 31
# Number of labels: 448 Number of images: 448
# Processing directory 32
# Number of labels: 448 Number of images: 448
# Processing directory 33
# Number of labels: 576 Number of images: 576
# Processing directory 34
# Number of labels: 448 Number of images: 448
# Processing directory 35
# Number of labels: 704 Number of images: 704
# Processing directory 36
# Number of labels: 448 Number of images: 448
# Processing directory 37
# Number of labels: 704 Number of images: 704
# Processing directory 38
# Number of labels: 640 Number of images: 640
# Processing directory 39
# Number of labels: 704 Number of images: 704
# Processing directory 40
# Number of labels: 512 Number of images: 512
# Processing directory 41
# Number of labels: 448 Number of images: 448
# Processing directory 42
# Number of labels: 704 Number of images: 704
# Processing directory 43
# Number of labels: 640 Number of images: 640
# Processing directory 44
# Number of labels: 448 Number of images: 448
# Processing directory 45
# Number of labels: 704 Number of images: 704
# Processing directory 46
# Number of labels: 704 Number of images: 704
# Processing directory 47
# Number of labels: 704 Number of images: 704
# Processing directory 48
# Number of labels: 768 Number of images: 768
# Processing directory 49
# Number of labels: 448 Number of images: 448
# Processing directory 50
# Number of labels: 704 Number of images: 704
# Processing directory 51
# Number of labels: 576 Number of images: 576
# Processing directory 52
# Number of labels: 448 Number of images: 448
# Processing directory 53
# Number of labels: 768 Number of images: 768
# Processing directory 54
# Number of labels: 512 Number of images: 512
# Processing directory 55
# Number of labels: 576 Number of images: 576
# Processing directory 56
# Number of labels: 448 Number of images: 448
# Processing directory 57
# Number of labels: 448 Number of images: 448
# Processing directory 58
# Number of labels: 448 Number of images: 448
# Processing directory 59
# Number of labels: 448 Number of images: 448
# Processing directory 60
# Number of labels: 576 Number of images: 576
# Processing directory 61
# Number of labels: 512 Number of images: 512
# Processing directory 62
# Number of labels: 448 Number of images: 448
# Processing directory 63
# Number of labels: 640 Number of images: 640
# Processing directory 64
# Number of labels: 576 Number of images: 576
# Processing directory 65
# Number of labels: 448 Number of images: 448
# Processing directory 66
# Number of labels: 448 Number of images: 448
# Processing directory 67
# Number of labels: 512 Number of images: 512
# Processing directory 68
# Number of labels: 448 Number of images: 448
# Processing directory 69
# Number of labels: 640 Number of images: 640
# Processing directory 70
# Number of labels: 576 Number of images: 576
# Processing directory 71
# Number of labels: 448 Number of images: 448
# Processing directory 72
# Number of labels: 512 Number of images: 512
# Processing directory 73
# Number of labels: 448 Number of images: 448
# Processing directory 74
# Number of labels: 448 Number of images: 448
# Processing directory 75
# Number of labels: 448 Number of images: 448
# Processing directory 76
# Number of labels: 40 Number of images: 40
# Processing directory 77
# Number of labels: 64 Number of images: 64
# Processing directory 78
# Number of labels: 64 Number of images: 64
# Processing directory 79
# Number of labels: 64 Number of images: 64
# Processing directory 80
# Number of labels: 64 Number of images: 64
# Processing directory 81
# Number of labels: 64 Number of images: 64
# Processing directory 82
# Number of labels: 64 Number of images: 64
# Processing directory 83
# Number of labels: 64 Number of images: 64
# Processing directory 84
# Number of labels: 64 Number of images: 64
# Processing directory 85
# Number of labels: 64 Number of images: 64
# Processing directory 86
# Number of labels: 64 Number of images: 64
# Processing directory 87
# Number of labels: 64 Number of images: 64
# Processing directory 88
# Number of labels: 64 Number of images: 64
# Processing directory 89
# Number of labels: 40 Number of images: 40
# Processing directory 90
# Number of labels: 64 Number of images: 64
# Processing directory 91
# Number of labels: 64 Number of images: 64
# Processing directory 92
# Number of labels: 64 Number of images: 64
# Processing directory 93
# Number of labels: 64 Number of images: 64
# Processing directory 94
# Number of labels: 64 Number of images: 64
# Processing directory 95
# Number of labels: 64 Number of images: 64
# Processing directory 96
# Number of labels: 64 Number of images: 64
# Processing directory 97
# Number of labels: 59 Number of images: 59
# Processing directory 98
# Number of labels: 64 Number of images: 64
# Processing directory 99
# Number of labels: 64 Number of images: 64
# Processing directory 100
# Number of labels: 64 Number of images: 64
# Processing directory 101
# Number of labels: 64 Number of images: 64
# Processing directory 102
# Number of labels: 64 Number of images: 64
# Processing directory 103
# Number of labels: 64 Number of images: 64
# Processing directory 104
# Number of labels: 64 Number of images: 64
# Processing directory 105
# Number of labels: 64 Number of images: 64
# Processing directory 106
# Number of labels: 64 Number of images: 64
# Processing directory 107
# Number of labels: 64 Number of images: 64
# Processing directory 108
# Number of labels: 64 Number of images: 64
# Processing directory 109
# Number of labels: 64 Number of images: 64
# Processing directory 110
# Number of labels: 64 Number of images: 64
# Processing directory 111
# Number of labels: 64 Number of images: 64
# Processing directory 112
# Number of labels: 64 Number of images: 64
# Processing directory 113
# Number of labels: 64 Number of images: 64
# Processing directory 114
# Number of labels: 64 Number of images: 64
# Processing directory 115
# Number of labels: 64 Number of images: 64
# Processing directory 116
# Number of labels: 64 Number of images: 64
# Processing directory 117
# Number of labels: 64 Number of images: 64
# Processing directory 118
# Number of labels: 64 Number of images: 64
# Processing directory 119
# Number of labels: 64 Number of images: 64
# Processing directory 120
# Number of labels: 64 Number of images: 64
# Processing directory 121
# Number of labels: 64 Number of images: 64
# Processing directory 122
# Number of labels: 64 Number of images: 64
# Processing directory 123
# Number of labels: 64 Number of images: 64
# Processing directory 124
# Number of labels: 64 Number of images: 64
# Processing directory 125
# Number of labels: 64 Number of images: 64
# Processing directory 126
# Number of labels: 64 Number of images: 64
# Processing directory 127
# Number of labels: 64 Number of images: 64
# Processing directory 128
# Number of labels: 64 Number of images: 64
# Processing directory 129
# Number of labels: 64 Number of images: 64
# Processing directory 130
# Number of labels: 64 Number of images: 64
# Processing directory 131
# Number of labels: 64 Number of images: 64
# Processing directory 132
# Number of labels: 64 Number of images: 64
# Processing directory 133
# Number of labels: 64 Number of images: 64
# Processing directory 134
# Number of labels: 64 Number of images: 64
# Processing directory 135
# Number of labels: 64 Number of images: 64
# Processing directory 136
# Number of labels: 64 Number of images: 64
# Processing directory 137
# Number of labels: 64 Number of images: 64
# Processing directory 138
# Number of labels: 64 Number of images: 64
# Processing directory 139
# Number of labels: 64 Number of images: 64
# Processing directory 140
# Number of labels: 64 Number of images: 64
# Processing directory 141
# Number of labels: 64 Number of images: 64
# Processing directory 142
# Number of labels: 64 Number of images: 64
# Processing directory 143
# Number of labels: 64 Number of images: 64
# Processing directory 144
# Number of labels: 64 Number of images: 64
# Processing directory 145
# Number of labels: 64 Number of images: 64
# Processing directory 146
# Number of labels: 64 Number of images: 64
# Processing directory 147
# Number of labels: 64 Number of images: 64
# Processing directory 148
# Number of labels: 64 Number of images: 64
# Processing directory 149
# Number of labels: 64 Number of images: 64
# Processing directory 150
# Number of labels: 64 Number of images: 64

# %%
import os

def rename_files_and_folders(folder_path, start_number=1):
    """
    Renames all files and folders in the specified folder with a given prefix and sequential numbers.

    :param folder_path: Path to the folder containing the files and folders to rename.
    :param prefix: Prefix to use for the renamed items.
    :param start_number: Starting number for the sequential naming.
    """
    try:
        items = sorted([int(i) for i in os.listdir(folder_path)])
        for count, item_name in enumerate(items, start=start_number):
            old_item_path = os.path.join(folder_path, str(item_name))
            
            if os.path.isdir(old_item_path):
                new_item_name = f'{count}'
            else:
                # Skip non-file/folder items
                continue
            
            new_item_path = os.path.join(folder_path, new_item_name)
            
            # Rename the item
            os.rename(old_item_path, new_item_path)
            print(f"Renamed: {item_name} -> {new_item_name}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Usage Example
folder_path = "quadrant_dataset"
rename_files_and_folders(folder_path)
# Out:
# Renamed: 1 -> 1
# Renamed: 2 -> 2
# Renamed: 3 -> 3
# Renamed: 4 -> 4
# Renamed: 5 -> 5
# Renamed: 6 -> 6
# Renamed: 7 -> 7
# Renamed: 8 -> 8
# Renamed: 9 -> 9
# Renamed: 10 -> 10
# Renamed: 11 -> 11
# Renamed: 12 -> 12
# Renamed: 13 -> 13
# Renamed: 14 -> 14
# Renamed: 15 -> 15
# Renamed: 16 -> 16
# Renamed: 17 -> 17
# Renamed: 18 -> 18
# Renamed: 19 -> 19
# Renamed: 20 -> 20
# Renamed: 21 -> 21
# Renamed: 22 -> 22
# Renamed: 23 -> 23
# Renamed: 24 -> 24
# Renamed: 25 -> 25
# Renamed: 26 -> 26
# Renamed: 27 -> 27
# Renamed: 28 -> 28
# Renamed: 29 -> 29
# Renamed: 30 -> 30
# Renamed: 31 -> 31
# Renamed: 32 -> 32
# Renamed: 33 -> 33
# Renamed: 34 -> 34
# Renamed: 35 -> 35
# Renamed: 36 -> 36
# Renamed: 479 -> 478
# Renamed: 480 -> 479
# Renamed: 481 -> 480
# Renamed: 482 -> 481
# Renamed: 483 -> 482
# Renamed: 484 -> 483
# Renamed: 485 -> 484
# Renamed: 486 -> 485
# Renamed: 487 -> 486
# Renamed: 488 -> 487
# Renamed: 489 -> 488
# Renamed: 490 -> 489
# Renamed: 491 -> 490
# Renamed: 492 -> 491
# Renamed: 493 -> 492
# Renamed: 494 -> 493
# Renamed: 495 -> 494
# Renamed: 496 -> 495
# Renamed: 497 -> 496
# Renamed: 498 -> 497
# Renamed: 499 -> 498
# Renamed: 500 -> 499
# Renamed: 501 -> 500
# Renamed: 502 -> 501
# Renamed: 503 -> 502
# Renamed: 504 -> 503
# Renamed: 505 -> 504
# Renamed: 506 -> 505
# Renamed: 507 -> 506
# Renamed: 508 -> 507
# Renamed: 509 -> 508
# Renamed: 510 -> 509
# Renamed: 511 -> 510
# Renamed: 512 -> 511
# Renamed: 513 -> 512
# Renamed: 514 -> 513
# Renamed: 515 -> 514
# Renamed: 516 -> 515
# Renamed: 517 -> 516
# Renamed: 518 -> 517
# Renamed: 519 -> 518
# Renamed: 520 -> 519
# Renamed: 521 -> 520
# Renamed: 522 -> 521
# Renamed: 523 -> 522
# Renamed: 524 -> 523
# Renamed: 525 -> 524
# Renamed: 526 -> 525
# Renamed: 527 -> 526
# Renamed: 528 -> 527
# Renamed: 529 -> 528
# Renamed: 530 -> 529
# Renamed: 531 -> 530
# Renamed: 532 -> 531
# Renamed: 533 -> 532
# Renamed: 534 -> 533
# Renamed: 535 -> 534
# Renamed: 536 -> 535
# Renamed: 537 -> 536
# Renamed: 538 -> 537
# Renamed: 539 -> 538
# Renamed: 540 -> 539
# Renamed: 541 -> 540
# Renamed: 542 -> 541
# Renamed: 543 -> 542
# Renamed: 544 -> 543
# Renamed: 545 -> 544
# Renamed: 546 -> 545
# Renamed: 547 -> 546
# Renamed: 548 -> 547
# Renamed: 549 -> 548
# Renamed: 550 -> 549
# Renamed: 551 -> 550
# Renamed: 552 -> 551
# Renamed: 553 -> 552
# Renamed: 554 -> 553
# Renamed: 555 -> 554
# Renamed: 556 -> 555
# Renamed: 557 -> 556
# Renamed: 558 -> 557
# Renamed: 559 -> 558
# Renamed: 560 -> 559
# Renamed: 561 -> 560
# Renamed: 562 -> 561
# Renamed: 563 -> 562

# %%
root = "goal_height_5"
file_ending = 'png'
file_name = "data_out.csv"
destination = "goal_height5_diff"

for i in range(len(os.listdir(root))):
    directory = i + 1
    print("Processing directory", directory)
    if not os.path.exists(f"{destination}/{str(directory)}"):
        os.makedirs(f"{destination}/{str(directory)}")
        
    csv_file_name = f"{root}/{str(directory)}/{file_name}"
    labels = np.genfromtxt(csv_file_name, delimiter=',', skip_header=1, dtype=np.float32)
    
    image_files = [fn for fn in os.listdir(f"./{root}/{str(directory)}") if file_ending in fn]
    n_images = len(image_files)

    # Load the goal images
    goal_image = cv2.imread(f'{root}/{str(directory)}/Image{n_images}.png')

    for i in range(1, n_images + 1):
        # Load the current image
        current_image = cv2.imread(f'{root}/{str(directory)}/Image{i}.png')

        # Compute the absolute difference between the images
        difference = cv2.absdiff(current_image, goal_image)

        # Save the result
        cv2.imwrite(f'{destination}/{str(directory)}/Image{i}.png', difference)
    
    columns = ['vx', 'vy', 'vz', 'omega_z']
    df = pd.DataFrame(labels, columns=columns)
    df.to_csv(f"{destination}/{directory}/{file_name}", index=False)
# Out:
# Processing directory 1
# Processing directory 2
# Processing directory 3
# Processing directory 4
# Processing directory 5
# Processing directory 6
# Processing directory 7
# Processing directory 8
# Processing directory 9
# Processing directory 10
# Processing directory 11
# Processing directory 12
# Processing directory 13
# Processing directory 14
# Processing directory 15
# Processing directory 16
# Processing directory 17
# Processing directory 18
# Processing directory 19
# Processing directory 20
# Processing directory 21
# Processing directory 22
# Processing directory 23
# Processing directory 24
# Processing directory 25
# Processing directory 26
# Processing directory 27
# Processing directory 28
# Processing directory 29
# Processing directory 30
# Processing directory 31
# Processing directory 32
# Processing directory 33
# Processing directory 34
# Processing directory 35
# Processing directory 36
# Processing directory 37
# Processing directory 38
# Processing directory 39
# Processing directory 40
# Processing directory 41
# Processing directory 42
# Processing directory 43
# Processing directory 44
# Processing directory 45
# Processing directory 46
# Processing directory 47
# Processing directory 48
# Processing directory 49
# Processing directory 50
# Processing directory 51
# Processing directory 52
# Processing directory 53
# Processing directory 54
# Processing directory 55
# Processing directory 56
# Processing directory 57
# Processing directory 58
# Processing directory 59
# Processing directory 60
# Processing directory 61
# Processing directory 62
# Processing directory 63
# Processing directory 64
# Processing directory 65
# Processing directory 66
# Processing directory 67
# Processing directory 68
# Processing directory 69
# Processing directory 70
# Processing directory 71
# Processing directory 72
# Processing directory 73
# Processing directory 74
# Processing directory 75
# Processing directory 76
# Processing directory 77
# Processing directory 78
# Processing directory 79
# Processing directory 80
# Processing directory 81
# Processing directory 82
# Processing directory 83
# Processing directory 84
# Processing directory 85
# Processing directory 86
# Processing directory 87
# Processing directory 88
# Processing directory 89
# Processing directory 90
# Processing directory 91
# Processing directory 92
# Processing directory 93
# Processing directory 94
# Processing directory 95
# Processing directory 96
# Processing directory 97
# Processing directory 98
# Processing directory 99
# Processing directory 100
# Processing directory 101
# Processing directory 102
# Processing directory 103
# Processing directory 104
# Processing directory 105
# Processing directory 106
# Processing directory 107
# Processing directory 108
# Processing directory 109
# Processing directory 110
# Processing directory 111
# Processing directory 112
# Processing directory 113
# Processing directory 114
# Processing directory 115
# Processing directory 116
# Processing directory 117
# Processing directory 118
# Processing directory 119
# Processing directory 120
# Processing directory 121
# Processing directory 122
# Processing directory 123
# Processing directory 124
# Processing directory 125
# Processing directory 126
# Processing directory 127
# Processing directory 128
# Processing directory 129
# Processing directory 130
# Processing directory 131
# Processing directory 132
# Processing directory 133
# Processing directory 134
# Processing directory 135
# Processing directory 136
# Processing directory 137
# Processing directory 138
# Processing directory 139
# Processing directory 140
# Processing directory 141
# Processing directory 142
# Processing directory 143
# Processing directory 144
# Processing directory 145
# Processing directory 146
# Processing directory 147
# Processing directory 148
# Processing directory 149
# Processing directory 150
